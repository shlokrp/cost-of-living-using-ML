# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# #  Working on dataset cost of living version 2 for year 2022

# %% [markdown]
# ## Reading the excel file of cost of living version 2

# %%
df = pd.read_excel('col_v2.xlsx')
df
# Out:
#                     city      country     x1     x2     x3     x4    x5    x6  \
# 0                  Seoul  South Korea   7.68  53.78   6.15   3.07  4.99  3.93
# 1               Shanghai        China   5.69  39.86   5.69   1.14  4.27  3.98
# 2              Guangzhou        China   4.13  28.47   4.98   0.85  1.71  3.54
# 3                 Mumbai        India   3.68  18.42   3.68   2.46  4.30  2.48
# 4                  Delhi        India   4.91  22.11   4.30   1.84  3.68  1.77
# ...                  ...          ...    ...    ...    ...    ...   ...   ...
# 4951        Peterborough    Australia    NaN    NaN    NaN    NaN   NaN   NaN
# 4952          Georgetown    Australia    NaN    NaN    NaN    NaN   NaN   NaN
# 4953  Ixtapa Zihuatanejo       Mexico   5.16  30.94  12.89   0.98   NaN  1.80
# 4954             Iqaluit       Canada  29.65  74.27  13.71   6.67  8.89  3.71
# 4955              Neiafu        Tonga    NaN  29.79  10.64  10.64   NaN   NaN
#
# ...

# %% [markdown]
# ## Dropping unwanted columns

# %%
df.drop(columns=['Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62'], inplace=True)

# %%
df
# Out:
#                     city      country     x1     x2     x3     x4    x5    x6  \
# 0                  Seoul  South Korea   7.68  53.78   6.15   3.07  4.99  3.93
# 1               Shanghai        China   5.69  39.86   5.69   1.14  4.27  3.98
# 2              Guangzhou        China   4.13  28.47   4.98   0.85  1.71  3.54
# 3                 Mumbai        India   3.68  18.42   3.68   2.46  4.30  2.48
# 4                  Delhi        India   4.91  22.11   4.30   1.84  3.68  1.77
# ...                  ...          ...    ...    ...    ...    ...   ...   ...
# 4951        Peterborough    Australia    NaN    NaN    NaN    NaN   NaN   NaN
# 4952          Georgetown    Australia    NaN    NaN    NaN    NaN   NaN   NaN
# 4953  Ixtapa Zihuatanejo       Mexico   5.16  30.94  12.89   0.98   NaN  1.80
# 4954             Iqaluit       Canada  29.65  74.27  13.71   6.67  8.89  3.71
# 4955              Neiafu        Tonga    NaN  29.79  10.64  10.64   NaN   NaN
#
# ...

# %% [markdown]
# ## Extracting a subset of the dataset for India

# %% [markdown]
# ### Creating a sub df for India

# %%
df_india = df[df['country']=='India']
df_india
# Out:
#                city country    x1     x2    x3    x4    x5    x6    x7    x8  \
# 3            Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19
# 4             Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19
# 16          Kolkata   India  2.00  14.74  3.68  2.21  3.68  1.64  0.36  0.15
# 24        Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18
# 26          Chennai   India  2.18  12.28  4.91  2.21  4.30  1.63  0.44  0.18
# ...             ...     ...   ...    ...   ...   ...   ...   ...   ...   ...
# 4868   Nallacheruvu   India  1.84   7.37  3.68  1.29  3.07  1.23  0.39  0.18
# 4895      Cherukuru   India  4.61   7.37  3.62  0.86  2.21  1.47  0.34  0.10
# 4907  Elakkurichchi   India  1.23   6.14  3.68  2.46  2.46  2.46  0.25  0.15
# 4909       Karavadi   India  1.35  11.05  3.56  1.04  2.15  1.56  0.78  0.21
# 4945       Tirupati   India  2.46   9.21  4.30  2.21  3.07  1.47  0.46  0.14
#
# ...

# %% [markdown]
# ### Working on 'x50' column

# %% [markdown]
# #### Finding null values in df_india for column x50 which is the column for rent for 3BHK apartment

# %%
null_x50 = df_india[df_india['x50'].isnull()]
null_x50
# Out:
#                city country    x1     x2    x3    x4    x5    x6    x7    x8  \
# 694      Saharanpur   India  2.15   6.14  5.53  1.54  2.70  0.98  0.40  0.18
# 821         Asansol   India  2.15  13.82  6.14  1.84  2.52  1.19  0.41  0.15
# 880      Ulhasnagar   India  1.23   4.91  1.84  2.46  3.07  0.74  0.36  0.14
# 920        Gulbarga   India  2.46   9.83  2.64  2.00  2.46  0.98  0.37  0.16
# 925          Dhulia   India   NaN   6.14  3.68  1.47  3.07   NaN  0.61  0.25
# 986          Sangli   India   NaN   9.83  3.07  2.00  2.46  0.98  0.37  0.16
# 1065       Kakinada   India  1.41   6.14  4.61  1.47  2.46  1.35   NaN  0.18
# 1068       Bhilwara   India  1.84   8.60  1.84  2.46  5.53  0.98  0.25  0.12
# 1294        Panipat   India  1.23  12.28  1.84  1.47  1.84  0.98  0.25  0.12
# 1356        Barasat   India  3.07    NaN  2.46  1.23  6.14  1.84  0.25  0.18
# 1394         Imphal   India  3.68  18.42  6.14  1.54  3.99  0.80  0.39  0.14
# ...

# %% [markdown]
# #### Creating another sub df 'df_india_2_1' that excludes rows having null values in 'x50' column

# %%
df_india_2_1 = df_india[~df_india.index.isin(null_x50.index)]
df_india_2_1
# Out:
#            city country    x1     x2    x3    x4    x5    x6    x7    x8  ...  \
# 3        Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19  ...
# 4         Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19  ...
# 16      Kolkata   India  2.00  14.74  3.68  2.21  3.68  1.64  0.36  0.15  ...
# 24    Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18  ...
# 26      Chennai   India  2.18  12.28  4.91  2.21  4.30  1.63  0.44  0.18  ...
# ...         ...     ...   ...    ...   ...   ...   ...   ...   ...   ...  ...
# 4535     Pakala   India  0.98   9.21  3.87  1.60  2.76  1.17  0.35  0.63  ...
# 4593  Dharmsala   India  1.11  12.28  2.46  1.47  2.58  0.98  0.43  0.18  ...
# 4677  Udayagiri   India  2.46  10.44  4.30  1.84  2.76  2.01  0.58  0.22  ...
# 4895  Cherukuru   India  4.61   7.37  3.62  0.86  2.21  1.47  0.34  0.10  ...
# 4945   Tirupati   India  2.46   9.21  4.30  2.21  3.07  1.47  0.46  0.14  ...
#
# ...

# %% [markdown]
# #### Verifying our modification

# %%
null_x50_2_1 = df_india_2_1[df_india_2_1['x50'].isnull()]
null_x50_2_1
# Out:
# Empty DataFrame
# Columns: [city, country, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, x13, x14, x15, x16, x17, x18, x19, x20, x21, x22, x23, x24, x25, x26, x27, x28, x29, x30, x31, x32, x33, x34, x35, x36, x37, x38, x39, x40, x41, x42, x43, x44, x45, x46, x47, x48, x49, x50, x51, x52, x53, x54, x55, data_quality]
# Index: []
#
# [0 rows x 58 columns]

# %% [markdown]
# ### Working on 'x54' column

# %% [markdown]
# #### Finding null values in df_india for column x54 which is the column for Average Monthly Salary

# %%
null_x54 = df_india[df_india['x54'].isnull()]
null_x54
# Out:
#                 city country    x1     x2    x3    x4    x5    x6    x7    x8  \
# 354          Dhanbad   India  4.30  12.28  3.07  1.72  2.21  1.35  0.39  0.16
# 694       Saharanpur   India  2.15   6.14  5.53  1.54  2.70  0.98  0.40  0.18
# 756         Raurkela   India  1.35   9.83  4.30  1.47  1.97  0.98  0.27  0.18
# 787           Tumkur   India  2.30   9.83  2.46  1.35  2.70  1.84  0.37  0.12
# 829        Bhavnagar   India  0.61   9.83  3.68  1.84  3.68  1.23  0.37  0.14
# 887           Jhansi   India  3.07   9.83  6.14  2.21   NaN  0.61  0.25  0.17
# 920         Gulbarga   India  2.46   9.83  2.64  2.00  2.46  0.98  0.37  0.16
# 925           Dhulia   India   NaN   6.14  3.68  1.47  3.07   NaN  0.61  0.25
# 950          Jalgaon   India  3.68   9.83  4.91  1.84  3.38  1.02  0.38  0.12
# 958          Kurnool   India   NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 986           Sangli   India   NaN   9.83  3.07  2.00  2.46  0.98  0.37  0.16
# ...

# %% [markdown]
# #### Creating another sub df 'df_india_2_2' that excludes rows having null values in 'x54' column

# %%
df_india_2_2 = df_india[~df_india.index.isin(null_x54.index)]
df_india_2_2
# Out:
#            city country    x1     x2    x3    x4    x5    x6    x7    x8  ...  \
# 3        Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19  ...
# 4         Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19  ...
# 16      Kolkata   India  2.00  14.74  3.68  2.21  3.68  1.64  0.36  0.15  ...
# 24    Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18  ...
# 26      Chennai   India  2.18  12.28  4.91  2.21  4.30  1.63  0.44  0.18  ...
# ...         ...     ...   ...    ...   ...   ...   ...   ...   ...   ...  ...
# 4535     Pakala   India  0.98   9.21  3.87  1.60  2.76  1.17  0.35  0.63  ...
# 4593  Dharmsala   India  1.11  12.28  2.46  1.47  2.58  0.98  0.43  0.18  ...
# 4677  Udayagiri   India  2.46  10.44  4.30  1.84  2.76  2.01  0.58  0.22  ...
# 4895  Cherukuru   India  4.61   7.37  3.62  0.86  2.21  1.47  0.34  0.10  ...
# 4945   Tirupati   India  2.46   9.21  4.30  2.21  3.07  1.47  0.46  0.14  ...
#
# ...

# %% [markdown]
# #### Verifying our modification

# %%
null_x50_2_2 = df_india_2_2[df_india_2_2['x54'].isnull()]
null_x50_2_2
# Out:
# Empty DataFrame
# Columns: [city, country, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, x13, x14, x15, x16, x17, x18, x19, x20, x21, x22, x23, x24, x25, x26, x27, x28, x29, x30, x31, x32, x33, x34, x35, x36, x37, x38, x39, x40, x41, x42, x43, x44, x45, x46, x47, x48, x49, x50, x51, x52, x53, x54, x55, data_quality]
# Index: []
#
# [0 rows x 58 columns]

# %% [markdown]
# ## Now we need to assign the level of city (Tier 1, Tier 2, Tier 3) to each city

# %% [markdown]
# ###  Checking based on 'x50' column

# %% [markdown]
# #### Sorting the df_india_2_1 based on 'x50' column in descending order

# %%
df_india_2_sorted_x50 = df_india_2_1.sort_values(by='x50', ascending=False)
df_india_2_sorted_x50.head(50)
# Out:
#                 city country    x1     x2    x3    x4    x5    x6    x7    x8  \
# 3             Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19
# 3859         Ponnuru   India  1.23   7.37  2.15  1.60  2.46  0.61  0.41  0.16
# 24         Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18
# 247            Thane   India  5.83  14.74  3.07  2.64  4.30  2.46  0.38  0.23
# 427          Jodhpur   India  2.46   9.83  3.68  1.84  3.99  1.45  0.25  0.12
# 4              Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19
# 1685         Gurgaon   India  4.91  18.42  3.68  1.84  3.68  2.13  0.45  0.21
# 361         Varanasi   India  3.07   8.04  3.07  1.84  3.38  1.57  0.35  0.18
# 51              Pune   India  3.68  14.74  4.30  2.46  3.68  1.96  0.42  0.16
# 50         Ahmedabad   India  2.46  12.28  3.68  3.38  5.53  1.68  0.44  0.18
# 235   Vishakhapatnam   India  2.46  10.44  4.30  1.84  2.76  2.01  0.58  0.22
# ...

# %% [markdown]
# #### Finding various values for 'x50' column

# %%
max_value = df_india_2_sorted_x50['x50'].max()
min_value = df_india_2_sorted_x50['x50'].min()
mean_value = df_india_2_sorted_x50['x50'].mean()
median_value = df_india_2_sorted_x50['x50'].median()
range_value = max_value - min_value

print(f"Max: {max_value}")
print(f"Min: {min_value}")
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Range: {range_value}")
# Out:
# Max: 1411.12
# Min: 73.69
# Mean: 256.14977941176465
# Median: 226.19
# Range: 1337.4299999999998

# %% [markdown]
# #### Plotting PDF for 'x50'

# %%
#pdf_x50 = df_india_2_1['x50'].plot().kde()
df_india_2_1['x50'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.boxplot(x=df_india_2_1['x50'])
# Out:
# <Axes: xlabel='x50'>

# %% [markdown]
# #### Capping Mumbai as it is important yet an outlier

# %%
# percentile_95 = np.percentile(df_india_2_1_1['x50'], 95)

# # Cap outliers at the 95th percentile
# # df_india_2_1_1 = df_india_2_1.loc[df_india_2_1['city'] == 'Mumbai', 'x50'] = min(df_india_2_1.loc[df_india_2_1['city'] == 'Mumbai', 'x50'], percentile_95)

# mumbai_x50 = df_india_2_1_1.loc[df_india_2_1_1['city'] == 'Mumbai', 'x50']
# mumbai_x50_capped = np.minimum(mumbai_x50, percentile_95)
# df_india_2_1.loc[df_india_2_1_1['city'] == 'Mumbai', 'x50'] = mumbai_x50_capped

# %% [markdown]
# ### Checking based on 'x54' column

# %% [markdown]
# #### Sorting the df_india_2_2 based on 'x54' column in descending order

# %%
df_india_2_sorted_x54 = df_india_2_2.sort_values(by='x54', ascending=False)
df_india_2_sorted_x54.head(50)
# Out:
#                     city country    x1     x2    x3    x4    x5    x6    x7  \
# 821              Asansol   India  2.15  13.82  6.14  1.84  2.52  1.19  0.41
# 907              Belgaum   India  1.23   6.14  3.07  2.33  3.68  1.43  0.33
# 24             Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46
# 1685             Gurgaon   India  4.91  18.42  3.68  1.84  3.68  2.13  0.45
# 51                  Pune   India  3.68  14.74  4.30  2.46  3.68  1.96  0.42
# 437               Mysore   India  1.04   7.37  4.34  1.23  3.99  2.15  0.38
# 2083            Shillong   India  3.68  13.51  3.68  1.47  3.99  1.39  0.49
# 661   Thiruvananthapuram   India  1.60   9.21  4.30  2.33  4.30  1.57  0.42
# 725               Guntur   India  2.46   9.83  4.91  1.84  2.82  1.80  0.53
# 1562              Karnal   India  1.84  10.44  3.44  1.97   NaN  1.47  0.49
# 3                 Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48
# ...

# %% [markdown]
# #### Finding various values for 'x54' column

# %%
max_value = df_india_2_sorted_x54['x54'].max()
min_value = df_india_2_sorted_x54['x54'].min()
mean_value = df_india_2_sorted_x54['x54'].mean()
median_value = df_india_2_sorted_x54['x54'].median()
range_value = max_value - min_value

print(f"Max: {max_value}")
print(f"Min: {min_value}")
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Range: {range_value}")
# Out:
# Max: 1105.36
# Min: 179.31
# Mean: 433.375785123967
# Median: 409.39
# Range: 926.05

# %% [markdown]
# #### Plotting PDF for 'x54'

# %%
df_india_2_2['x54'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.boxplot(x=df_india_2_2['x54'])
# Out:
# <Axes: xlabel='x54'>

# %% [markdown]
# #### We have decided to divide the dataframe df_india_2_1 into tiers based on the average income feature that is 'x50'

# %% [markdown]
# ### Making a new column 'Tier' in df_india_2_1 and assigning values based on 'x50'

# %%
df_india_2_1
# Out:
#            city country    x1     x2    x3    x4    x5    x6    x7    x8  ...  \
# 3        Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19  ...
# 4         Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19  ...
# 16      Kolkata   India  2.00  14.74  3.68  2.21  3.68  1.64  0.36  0.15  ...
# 24    Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18  ...
# 26      Chennai   India  2.18  12.28  4.91  2.21  4.30  1.63  0.44  0.18  ...
# ...         ...     ...   ...    ...   ...   ...   ...   ...   ...   ...  ...
# 4535     Pakala   India  0.98   9.21  3.87  1.60  2.76  1.17  0.35  0.63  ...
# 4593  Dharmsala   India  1.11  12.28  2.46  1.47  2.58  0.98  0.43  0.18  ...
# 4677  Udayagiri   India  2.46  10.44  4.30  1.84  2.76  2.01  0.58  0.22  ...
# 4895  Cherukuru   India  4.61   7.37  3.62  0.86  2.21  1.47  0.34  0.10  ...
# 4945   Tirupati   India  2.46   9.21  4.30  2.21  3.07  1.47  0.46  0.14  ...
#
# ...

# %% [markdown]
# #### Making bins of different sizes from column 'x50'(Rent 3BHK) ; sizes are (0-150,150-400,400+)

# %%
bins = [0,150,400,float('inf')]
bin_labels = ['0-150', '150-400', '400+']
df_india_2_1["x50_binned"] = pd.cut(df["x50"], bins)
df_india_2_1.head(60)
# Out:
# /var/folders/qc/b4s6ptms5f73v6qv3yd1zxn00000gn/T/ipykernel_91935/4264286105.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_india_2_1["x50_binned"] = pd.cut(df["x50"], bins)
#                    city country    x1     x2    x3    x4    x5    x6    x7  \
# 3                Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48
# 4                 Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49
# 16              Kolkata   India  2.00  14.74  3.68  2.21  3.68  1.64  0.36
# 24            Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46
# 26              Chennai   India  2.18  12.28  4.91  2.21  4.30  1.63  0.44
# 30            Hyderabad   India  2.46  12.28  5.53  1.84  3.68  2.01  0.45
# ...

# %%
df_india_2_1
# Out:
#            city country    x1     x2    x3    x4    x5    x6    x7    x8  ...  \
# 3        Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19  ...
# 4         Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19  ...
# 16      Kolkata   India  2.00  14.74  3.68  2.21  3.68  1.64  0.36  0.15  ...
# 24    Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18  ...
# 26      Chennai   India  2.18  12.28  4.91  2.21  4.30  1.63  0.44  0.18  ...
# ...         ...     ...   ...    ...   ...   ...   ...   ...   ...   ...  ...
# 4535     Pakala   India  0.98   9.21  3.87  1.60  2.76  1.17  0.35  0.63  ...
# 4593  Dharmsala   India  1.11  12.28  2.46  1.47  2.58  0.98  0.43  0.18  ...
# 4677  Udayagiri   India  2.46  10.44  4.30  1.84  2.76  2.01  0.58  0.22  ...
# 4895  Cherukuru   India  4.61   7.37  3.62  0.86  2.21  1.47  0.34  0.10  ...
# 4945   Tirupati   India  2.46   9.21  4.30  2.21  3.07  1.47  0.46  0.14  ...
#
# ...

# %% [markdown]
# #### Assigining Tiers to all the cities based on the 'x50' column

# %%
df_india_2_1.loc[df_india_2_1['x50'] > 400, 'tier'] = 'Tier 1'
df_india_2_1.loc[(df_india_2_1['x50'] <= 400) & (df_india_2_1['x50'] > 150), 'tier'] = 'Tier 2'
df_india_2_1.loc[df_india_2_1['x50'] <= 150, 'tier'] = 'Tier 3'
# Out:
# /var/folders/qc/b4s6ptms5f73v6qv3yd1zxn00000gn/T/ipykernel_91935/787837137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_india_2_1.loc[df_india_2_1['x50'] > 400, 'tier'] = 'Tier 1'

# %%
df_india_2_1
# Out:
#            city country    x1     x2    x3    x4    x5    x6    x7    x8  ...  \
# 3        Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19  ...
# 4         Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19  ...
# 16      Kolkata   India  2.00  14.74  3.68  2.21  3.68  1.64  0.36  0.15  ...
# 24    Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18  ...
# 26      Chennai   India  2.18  12.28  4.91  2.21  4.30  1.63  0.44  0.18  ...
# ...         ...     ...   ...    ...   ...   ...   ...   ...   ...   ...  ...
# 4535     Pakala   India  0.98   9.21  3.87  1.60  2.76  1.17  0.35  0.63  ...
# 4593  Dharmsala   India  1.11  12.28  2.46  1.47  2.58  0.98  0.43  0.18  ...
# 4677  Udayagiri   India  2.46  10.44  4.30  1.84  2.76  2.01  0.58  0.22  ...
# 4895  Cherukuru   India  4.61   7.37  3.62  0.86  2.21  1.47  0.34  0.10  ...
# 4945   Tirupati   India  2.46   9.21  4.30  2.21  3.07  1.47  0.46  0.14  ...
#
# ...

# %% [markdown]
# #### Sorting based on 'x50' values in descending order

# %%
df_india_2_1.sort_values(by='x50', ascending=False).head(50)
# Out:
#                 city country    x1     x2    x3    x4    x5    x6    x7    x8  \
# 3             Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19
# 3859         Ponnuru   India  1.23   7.37  2.15  1.60  2.46  0.61  0.41  0.16
# 24         Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18
# 247            Thane   India  5.83  14.74  3.07  2.64  4.30  2.46  0.38  0.23
# 427          Jodhpur   India  2.46   9.83  3.68  1.84  3.99  1.45  0.25  0.12
# 4              Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19
# 1685         Gurgaon   India  4.91  18.42  3.68  1.84  3.68  2.13  0.45  0.21
# 361         Varanasi   India  3.07   8.04  3.07  1.84  3.38  1.57  0.35  0.18
# 51              Pune   India  3.68  14.74  4.30  2.46  3.68  1.96  0.42  0.16
# 50         Ahmedabad   India  2.46  12.28  3.68  3.38  5.53  1.68  0.44  0.18
# 235   Vishakhapatnam   India  2.46  10.44  4.30  1.84  2.76  2.01  0.58  0.22
# ...

# %% [markdown]
# #### Verifying our progress

# %%
df_india_2_1
# Out:
#            city country    x1     x2    x3    x4    x5    x6    x7    x8  ...  \
# 3        Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19  ...
# 4         Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19  ...
# 16      Kolkata   India  2.00  14.74  3.68  2.21  3.68  1.64  0.36  0.15  ...
# 24    Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18  ...
# 26      Chennai   India  2.18  12.28  4.91  2.21  4.30  1.63  0.44  0.18  ...
# ...         ...     ...   ...    ...   ...   ...   ...   ...   ...   ...  ...
# 4535     Pakala   India  0.98   9.21  3.87  1.60  2.76  1.17  0.35  0.63  ...
# 4593  Dharmsala   India  1.11  12.28  2.46  1.47  2.58  0.98  0.43  0.18  ...
# 4677  Udayagiri   India  2.46  10.44  4.30  1.84  2.76  2.01  0.58  0.22  ...
# 4895  Cherukuru   India  4.61   7.37  3.62  0.86  2.21  1.47  0.34  0.10  ...
# 4945   Tirupati   India  2.46   9.21  4.30  2.21  3.07  1.47  0.46  0.14  ...
#
# ...

# %%
df_india_2_1.isnull().sum()
# Out:
# city             0
# country          0
# x1               4
# x2               4
# x3               3
# x4               4
# x5              12
# x6               9
# x7               2
# x8               2
# x9               1
# x10              2
# x11              2
# x12              2
# x13              7
# x14              7
# x15             11
# x16             12
# x17              3
# x18              6
# x19             10
# x20             11
# x21              2
# x22             15
# x23              1
# x24             11
# x25             11
# x26             20
# x27             12
# x28             13
# x29             30
# x30             16
# x31             12
# x32             25
# x33              3
# x34             22
# x35             19
# x36             10
# x37             13
# x38              3
# x39             11
# x40             34
# x41              3
# x42              8
# x43             17
# x44              4
# x45             11
# ...

# %% [markdown]
# ## Working on features - Feature Selection and Extraction

# %% [markdown]
# ### Plotting a heatmap for the India dataset with tier assigned to cities

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

bubu = df_india_2_1.corr()

plt.figure(figsize = (15,8))
sns.heatmap(bubu, annot = True)
# Out:
# /var/folders/qc/b4s6ptms5f73v6qv3yd1zxn00000gn/T/ipykernel_91935/1515183809.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bubu = df_india_2_1.corr()
# <Axes: >

# %% [markdown]
# ### Making a new column 'COL' which stands for the overall Cost Of Living for each city

# %% [markdown]
# #### COL is a combination of various different columns which are basic neccessities for survival

# %%
df_india_2_1['COL'] = df_india_2_1['x9'] * 10 + df_india_2_1['x11'] * 12 + df_india_2_1['x12'] * 0.5 + df_india_2_1['x16'] * 1.5 + df_india_2_1['x17'] * 6 + df_india_2_1['x18'] * 1.5 + df_india_2_1['x19'] * 3 + df_india_2_1['x20'] * 3 + df_india_2_1['x21'] * 2 + df_india_2_1['x22'] + df_india_2_1['x33'] * 12 + df_india_2_1['x36'] + df_india_2_1['x48']
# Out:
# /var/folders/qc/b4s6ptms5f73v6qv3yd1zxn00000gn/T/ipykernel_91935/3247693671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_india_2_1['COL'] = df_india_2_1['x9'] * 10 + df_india_2_1['x11'] * 12 + df_india_2_1['x12'] * 0.5 + df_india_2_1['x16'] * 1.5 + df_india_2_1['x17'] * 6 + df_india_2_1['x18'] * 1.5 + df_india_2_1['x19'] * 3 + df_india_2_1['x20'] * 3 + df_india_2_1['x21'] * 2 + df_india_2_1['x22'] + df_india_2_1['x33'] * 12 + df_india_2_1['x36'] + df_india_2_1['x48']

# %%
df_india_2_1.head(50)
# Out:
#                city country    x1     x2    x3    x4    x5    x6    x7    x8  \
# 3            Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19
# 4             Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19
# 16          Kolkata   India  2.00  14.74  3.68  2.21  3.68  1.64  0.36  0.15
# 24        Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18
# 26          Chennai   India  2.18  12.28  4.91  2.21  4.30  1.63  0.44  0.18
# 30        Hyderabad   India  2.46  12.28  5.53  1.84  3.68  2.01  0.45  0.18
# 50        Ahmedabad   India  2.46  12.28  3.68  3.38  5.53  1.68  0.44  0.18
# 51             Pune   India  3.68  14.74  4.30  2.46  3.68  1.96  0.42  0.16
# 89        Allahabad   India  1.84   6.14  3.68  1.66  2.46  2.15  0.64  0.20
# 110           Surat   India  2.76   9.83  3.68  1.84  3.68  1.35  0.37  0.18
# 153         Lucknow   India  3.07  12.28  3.07  1.84  3.68  1.57  0.35  0.18
# ...

# %%
df_india_2_1
# Out:
#            city country    x1     x2    x3    x4    x5    x6    x7    x8  ...  \
# 3        Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19  ...
# 4         Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19  ...
# 16      Kolkata   India  2.00  14.74  3.68  2.21  3.68  1.64  0.36  0.15  ...
# 24    Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18  ...
# 26      Chennai   India  2.18  12.28  4.91  2.21  4.30  1.63  0.44  0.18  ...
# ...         ...     ...   ...    ...   ...   ...   ...   ...   ...   ...  ...
# 4535     Pakala   India  0.98   9.21  3.87  1.60  2.76  1.17  0.35  0.63  ...
# 4593  Dharmsala   India  1.11  12.28  2.46  1.47  2.58  0.98  0.43  0.18  ...
# 4677  Udayagiri   India  2.46  10.44  4.30  1.84  2.76  2.01  0.58  0.22  ...
# 4895  Cherukuru   India  4.61   7.37  3.62  0.86  2.21  1.47  0.34  0.10  ...
# 4945   Tirupati   India  2.46   9.21  4.30  2.21  3.07  1.47  0.46  0.14  ...
#
# ...

# %% [markdown]
# #### Checking for null values and dropping rows that have insufficient values to calculate COL

# %%
df_india_2_1['COL'].isnull().sum()
# Out:
# 23

# %%
df_india_2_1_cleaned = df_india_2_1.dropna(subset=['COL'])
df_india_2_1_cleaned
# Out:
#            city country    x1     x2    x3    x4    x5    x6    x7    x8  ...  \
# 3        Mumbai   India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19  ...
# 4         Delhi   India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19  ...
# 16      Kolkata   India  2.00  14.74  3.68  2.21  3.68  1.64  0.36  0.15  ...
# 24    Bangalore   India  3.07  18.42  4.30  2.21  3.68  2.09  0.46  0.18  ...
# 26      Chennai   India  2.18  12.28  4.91  2.21  4.30  1.63  0.44  0.18  ...
# ...         ...     ...   ...    ...   ...   ...   ...   ...   ...   ...  ...
# 4225   Udhampur   India  1.60  10.44  2.76  1.84  1.97  0.86  0.34  0.20  ...
# 4593  Dharmsala   India  1.11  12.28  2.46  1.47  2.58  0.98  0.43  0.18  ...
# 4677  Udayagiri   India  2.46  10.44  4.30  1.84  2.76  2.01  0.58  0.22  ...
# 4895  Cherukuru   India  4.61   7.37  3.62  0.86  2.21  1.47  0.34  0.10  ...
# 4945   Tirupati   India  2.46   9.21  4.30  2.21  3.07  1.47  0.46  0.14  ...
#
# ...

# %%
df_india_2_1_cleaned['COL']
# Out:
# 3       613.890
# 4       333.990
# 16      224.335
# 24      310.190
# 26      260.190
#          ...
# 4225    159.440
# 4593    209.750
# 4677    136.850
# 4895    116.230
# 4945    148.820
# Name: COL, Length: 113, dtype: float64

# %% [markdown]
# ### Making a new sub-df out of the cleaned dataframe of India df_india_final having city, country, tier and COL columns

# %%
selected_columns = ['city', 'country', 'tier', 'COL']

df_india_final = df_india_2_1_cleaned[selected_columns]
df_india_final
# Out:
#            city country    tier      COL
# 3        Mumbai   India  Tier 1  613.890
# 4         Delhi   India  Tier 1  333.990
# 16      Kolkata   India  Tier 2  224.335
# 24    Bangalore   India  Tier 1  310.190
# 26      Chennai   India  Tier 1  260.190
# ...         ...     ...     ...      ...
# 4225   Udhampur   India  Tier 2  159.440
# 4593  Dharmsala   India  Tier 2  209.750
# 4677  Udayagiri   India  Tier 3  136.850
# 4895  Cherukuru   India  Tier 3  116.230
# 4945   Tirupati   India  Tier 2  148.820
#
# [113 rows x 4 columns]

# %% [markdown]
# ### Renaming the COL column to COL_2022 as all the above data was for Year 2022

# %%
df_india_final = df_india_final.rename(columns={'COL': 'COL_2022'})
df_india_final
# Out:
#            city country    tier  COL_2022
# 3        Mumbai   India  Tier 1   613.890
# 4         Delhi   India  Tier 1   333.990
# 16      Kolkata   India  Tier 2   224.335
# 24    Bangalore   India  Tier 1   310.190
# 26      Chennai   India  Tier 1   260.190
# ...         ...     ...     ...       ...
# 4225   Udhampur   India  Tier 2   159.440
# 4593  Dharmsala   India  Tier 2   209.750
# 4677  Udayagiri   India  Tier 3   136.850
# 4895  Cherukuru   India  Tier 3   116.230
# 4945   Tirupati   India  Tier 2   148.820
#
# [113 rows x 4 columns]

# %% [markdown]
# # Working on dataset Inflation

# %% [markdown]
# ## Reading the excel file of Gloabal Inflation Data

# %%
df_inflation = pd.read_excel('inflation.xlsx')
df_inflation
# Out:
#     Country Code  IMF Country Code               Country Indicator Type  \
# 0            ABW             314.0                 Aruba      Inflation
# 1            AFG             512.0           Afghanistan      Inflation
# 2            AGO             614.0                Angola      Inflation
# 3            ALB             914.0               Albania      Inflation
# 4            ARE             466.0  United Arab Emirates      Inflation
# ..           ...               ...                   ...            ...
# 778          VEN             299.0         Venezuela, RB      Inflation
# 779          VNM             582.0               Vietnam      Inflation
# 780          XKX             967.0                Kosovo      Inflation
# 781          ZAF             199.0          South Africa      Inflation
# 782          ZMB             754.0                Zambia      Inflation
#
#                            Series Name   1970   1971   1972   1973   1974  \
# ...

# %% [markdown]
# ## Making a sub-df for India's historical inflation data

# %%
df_inflation_india = df_inflation[(df_inflation['Country'] == 'India') & (df_inflation['Series Name'] == 'Headline Consumer Price Inflation')]
df_inflation_india
# Out:
#    Country Code  IMF Country Code Country Indicator Type  \
# 79          IND             534.0   India      Inflation
#
#                           Series Name  1970  1971  1972   1973  1974  ...  \
# 79  Headline Consumer Price Inflation   5.1  3.08  6.44  16.94  28.6  ...
#
#     2015  2016  2017  2018  2019  2020  2021  2022                      Note  \
# 79  5.87  4.94   3.6  4.86  4.76  6.62  4.89  6.69  Annual average inflation
#
#     Column1
# 79      NaN
#
# [1 rows x 60 columns]

# %% [markdown]
# ### Checking for null values, dropping unwanted columns and renaming column as per need

# %%
df_inflation_india.isnull().sum()
# Out:
# Country Code        0
# IMF Country Code    0
# Country             0
# Indicator Type      0
# Series Name         0
# 1970                0
# 1971                0
# 1972                0
# 1973                0
# 1974                0
# 1975                0
# 1976                0
# 1977                0
# 1978                0
# 1979                0
# 1980                0
# 1981                0
# 1982                0
# 1983                0
# 1984                0
# 1985                0
# 1986                0
# 1987                0
# 1988                0
# 1989                0
# 1990                0
# 1991                0
# 1992                0
# 1993                0
# 1994                0
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0
# 2000                0
# 2001                0
# 2002                0
# 2003                0
# 2004                0
# 2005                0
# ...

# %%
#df_inflation_india = df_inflation_india.drop('Column1', axis=1)
df_inflation_india
# Out:
#    Country Code  IMF Country Code Country Indicator Type  \
# 79          IND             534.0   India      Inflation
#
#                           Series Name  1970  1971  1972   1973  1974  ...  \
# 79  Headline Consumer Price Inflation   5.1  3.08  6.44  16.94  28.6  ...
#
#     2015  2016  2017  2018  2019  2020  2021  2022                      Note  \
# 79  5.87  4.94   3.6  4.86  4.76  6.62  4.89  6.69  Annual average inflation
#
#     Column1
# 79      NaN
#
# [1 rows x 60 columns]

# %%
df_inflation_india = df_inflation_india.rename(columns={'Country': 'country'})
df_inflation_india
# Out:
#    Country Code  IMF Country Code country Indicator Type  \
# 79          IND             534.0   India      Inflation
#
#                           Series Name  1970  1971  1972   1973  1974  ...  \
# 79  Headline Consumer Price Inflation   5.1  3.08  6.44  16.94  28.6  ...
#
#     2015  2016  2017  2018  2019  2020  2021  2022                      Note  \
# 79  5.87  4.94   3.6  4.86  4.76  6.62  4.89  6.69  Annual average inflation
#
#     Column1
# 79      NaN
#
# [1 rows x 60 columns]

# %%
df_inflation_india_3 = df_inflation_india.drop(['Country Code','IMF Country Code','Indicator Type','Series Name','Note'], axis=1)
df_inflation_india_3
# Out:
#    country  1970  1971  1972   1973  1974  1975  1976  1977  1978  ...  2014  \
# 79   India   5.1  3.08  6.44  16.94  28.6  5.75 -7.63  8.31  2.52  ...  6.35
#
#     2015  2016  2017  2018  2019  2020  2021  2022  Column1
# 79  5.87  4.94   3.6  4.86  4.76  6.62  4.89  6.69      NaN
#
# [1 rows x 55 columns]

# %%
import os
current_directory = os.getcwd()

# %%
file_name = 'inflation_india1.xlsx'
file_path = os.path.join(current_directory, file_name)

# %%
df_inflation_india_3.to_excel(file_path, index=False, engine='openpyxl')

# %%
df_inflation_india['2022']
# Out:
# 79    6.69
# Name: 2022, dtype: float64

# %% [markdown]
# ## Merging the initial COL dataset of India

# %%
merged_df = pd.merge(df_india_final, df_inflation_india[['country', '2022']], on='country', how='left')

# Rename the inflation rate column for clarity
merged_df.rename(columns={'2022': 'inflation_2022'}, inplace=True)

# Calculate COL_2021 based on the formula
merged_df['COL_2021'] = merged_df['COL_2022'] / (1 +( merged_df['inflation_2022'])/100)

# Display or use the updated dataframe with 'COL_2021'
merged_df.head(50)
# Out:
#               city country    tier  COL_2022  inflation_2022    COL_2021
# 0           Mumbai   India  Tier 1   613.890            6.69  575.396007
# 1            Delhi   India  Tier 1   333.990            6.69  313.047146
# 2          Kolkata   India  Tier 2   224.335            6.69  210.268066
# 3        Bangalore   India  Tier 1   310.190            6.69  290.739526
# 4          Chennai   India  Tier 1   260.190            6.69  243.874777
# 5        Hyderabad   India  Tier 1   249.750            6.69  234.089418
# 6        Ahmedabad   India  Tier 1   544.225            6.69  510.099353
# 7             Pune   India  Tier 1   291.780            6.69  273.483925
# 8        Allahabad   India  Tier 2   179.605            6.69  168.342862
# 9            Surat   India  Tier 2   299.395            6.69  280.621427
# 10         Lucknow   India  Tier 2   211.600            6.69  198.331615
# 11          Jaipur   India  Tier 2   233.065            6.69  218.450651
# ...

# %% [markdown]
# # Final checkpoint upto today - 01/12/2023

# %%
merged_df.drop('inflation_2022', axis = 1)
# Out:
#           city country    tier  COL_2022    COL_2021
# 0       Mumbai   India  Tier 1   613.890  575.396007
# 1        Delhi   India  Tier 1   333.990  313.047146
# 2      Kolkata   India  Tier 2   224.335  210.268066
# 3    Bangalore   India  Tier 1   310.190  290.739526
# 4      Chennai   India  Tier 1   260.190  243.874777
# ..         ...     ...     ...       ...         ...
# 108   Udhampur   India  Tier 2   159.440  149.442309
# 109  Dharmsala   India  Tier 2   209.750  196.597619
# 110  Udayagiri   India  Tier 3   136.850  128.268816
# 111  Cherukuru   India  Tier 3   116.230  108.941794
# 112   Tirupati   India  Tier 2   148.820  139.488237
#
# [113 rows x 5 columns]

# %% [markdown]
# # Resuming work on 18/12/2023

# %% [markdown]
# ## Continuing work on merged_df to backtrack for more year(probably upto 2012)

# %% [markdown]
# ### Making a merged_df_2 as a new dataframe having the cost of living values of years backtracked to 2013 using inflation dataset

# %% [markdown]
# #### Backtracking

# %%
merged_df = pd.merge(df_india_final, df_inflation_india[['country', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013']], on='country', how='left')

# Rename the inflation rate column for clarity
merged_df.rename(columns={'2022': 'inflation_2022', '2021':'inflation_2021','2020':'inflation_2020', '2019':'inflation_2019', '2018':'inflation_2018', '2017':'inflation_2017', '2016':'inflation_2016', '2015':'inflation_2015', '2014':'inflation_2014', '2013':'inflation_2013'}, inplace=True)

# Calculate COL_2021 based on the formula
merged_df['COL_2021'] = merged_df['COL_2022'] / (1 +( merged_df['inflation_2022'])/100)
merged_df['COL_2020'] = merged_df['COL_2021'] / (1 +( merged_df['inflation_2021'])/100)
merged_df['COL_2019'] = merged_df['COL_2020'] / (1 +( merged_df['inflation_2020'])/100)
merged_df['COL_2018'] = merged_df['COL_2019'] / (1 +( merged_df['inflation_2019'])/100)
merged_df['COL_2017'] = merged_df['COL_2018'] / (1 +( merged_df['inflation_2018'])/100)
merged_df['COL_2016'] = merged_df['COL_2017'] / (1 +( merged_df['inflation_2017'])/100)
merged_df['COL_2015'] = merged_df['COL_2016'] / (1 +( merged_df['inflation_2016'])/100)
merged_df['COL_2014'] = merged_df['COL_2015'] / (1 +( merged_df['inflation_2015'])/100)
merged_df['COL_2013'] = merged_df['COL_2014'] / (1 +( merged_df['inflation_2014'])/100)
merged_df['COL_2012'] = merged_df['COL_2013'] / (1 +( merged_df['inflation_2013'])/100)

# Display or use the updated dataframe with 'COL_2021'
merged_df
# Out:
#           city country    tier  COL_2022  inflation_2022  inflation_2021  \
# 0       Mumbai   India  Tier 1   613.890            6.69            4.89
# 1        Delhi   India  Tier 1   333.990            6.69            4.89
# 2      Kolkata   India  Tier 2   224.335            6.69            4.89
# 3    Bangalore   India  Tier 1   310.190            6.69            4.89
# 4      Chennai   India  Tier 1   260.190            6.69            4.89
# ..         ...     ...     ...       ...             ...             ...
# 108   Udhampur   India  Tier 2   159.440            6.69            4.89
# 109  Dharmsala   India  Tier 2   209.750            6.69            4.89
# 110  Udayagiri   India  Tier 3   136.850            6.69            4.89
# 111  Cherukuru   India  Tier 3   116.230            6.69            4.89
# 112   Tirupati   India  Tier 2   148.820            6.69            4.89
#
#      inflation_2020  inflation_2019  inflation_2018  inflation_2017  ...  \
# ...

# %% [markdown]
# #### Dropping unwanted columns

# %%
merged_df.drop(columns = ['inflation_2022', 'inflation_2021', 'inflation_2020', 'inflation_2019', 'inflation_2018', 'inflation_2017', 'inflation_2016', 'inflation_2015', 'inflation_2014', 'inflation_2013'], axis = 1, inplace=True)

# %%
merged_df
# Out:
#           city country    tier  COL_2022    COL_2021    COL_2020    COL_2019  \
# 0       Mumbai   India  Tier 1   613.890  575.396007  548.570891  514.510308
# 1        Delhi   India  Tier 1   333.990  313.047146  298.452804  279.921969
# 2      Kolkata   India  Tier 2   224.335  210.268066  200.465313  188.018489
# 3    Bangalore   India  Tier 1   310.190  290.739526  277.185171  259.974837
# 4      Chennai   India  Tier 1   260.190  243.874777  232.505270  218.069096
# ..         ...     ...     ...       ...         ...         ...         ...
# 108   Udhampur   India  Tier 2   159.440  149.442309  142.475269  133.629027
# 109  Dharmsala   India  Tier 2   209.750  196.597619  187.432185  175.794584
# 110  Udayagiri   India  Tier 3   136.850  128.268816  122.288889  114.696013
# 111  Cherukuru   India  Tier 3   116.230  108.941794  103.862898   97.414086
# 112   Tirupati   India  Tier 2   148.820  139.488237  132.985258  124.728248
#
# ...

# %% [markdown]
# #### Plotting heatmap to check the correlation between all the features

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

bubu = merged_df.corr()

plt.figure(figsize = (10,6))
sns.heatmap(bubu, annot = True)
# Out:
# /var/folders/qc/b4s6ptms5f73v6qv3yd1zxn00000gn/T/ipykernel_91935/1820632254.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bubu = merged_df.corr()
# <Axes: >

# %% [markdown]
# ### Trying this Linear Regression model by duplicating merged_df into merged_df_2

# %%
merged_df_2 = merged_df.copy()

# %% [markdown]
# #### All the features seem to be havind +1 correlation because all of them are related and are extracted from one 'COL_2022' using inflation rates so that's why

# %% [markdown]
# #### Encoding the categorical variables 'city' and 'tier' and dropping 'country' as it has the same value for all the rows

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

merged_df_2['city_enc'] = le.fit_transform(merged_df_2['city'])
merged_df_2.drop(['city'], axis = 1, inplace=True)

merged_df_2['country_enc'] = le.fit_transform(merged_df_2['country'])
merged_df_2.drop(['country'], axis = 1, inplace=True)

merged_df_2['tier_enc'] = le.fit_transform(merged_df_2['tier'])
merged_df_2.drop(['tier'], axis = 1, inplace=True)

# %%
merged_df_2.drop(['country_enc'], axis=1, inplace=True)
merged_df_2
# Out:
#      COL_2022    COL_2021    COL_2020    COL_2019    COL_2018    COL_2017  \
# 0     613.890  575.396007  548.570891  514.510308  491.132406  468.369641
# 1     333.990  313.047146  298.452804  279.921969  267.203102  254.818903
# 2     224.335  210.268066  200.465313  188.018489  179.475457  171.157216
# 3     310.190  290.739526  277.185171  259.974837  248.162311  236.660605
# 4     260.190  243.874777  232.505270  218.069096  208.160649  198.512921
# ..        ...         ...         ...         ...         ...         ...
# 108   159.440  149.442309  142.475269  133.629027  127.557300  121.645336
# 109   209.750  196.597619  187.432185  175.794584  167.806972  160.029537
# 110   136.850  128.268816  122.288889  114.696013  109.484549  104.410213
# 111   116.230  108.941794  103.862898   97.414086   92.987863   88.678107
# 112   148.820  139.488237  132.985258  124.728248  119.060947  113.542768
#
#        COL_2016    COL_2015    COL_2014    COL_2013    COL_2012  city_enc  \
# ...

# %% [markdown]
# #### Splitting the dataset into training and testing set, also making the COL_2022 variable as the y(output/dependent/target) variable

# %%
from sklearn.model_selection import train_test_split

X = merged_df_2.drop('COL_2022', axis = 1)
y = merged_df_2['COL_2022']

X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.33, random_state=42)

X_train
# Out:
#        COL_2021    COL_2020    COL_2019    COL_2018    COL_2017    COL_2016  \
# 28   187.280907  178.549821  167.463723  159.854642  152.445777  147.148433
# 42   169.978442  162.054002  151.992123  145.086028  138.361652  133.553718
# 5    234.089418  223.176106  209.319177  199.808302  190.547684  183.926336
# 55   170.887618  162.920792  152.805094  145.862060  139.101717  134.268066
# 64   229.187365  218.502589  204.935836  195.624128  186.557436  180.074746
# ..          ...         ...         ...         ...         ...         ...
# 106  207.320274  197.654947  185.382618  176.959352  168.757727  162.893559
# 14   162.737839  155.150957  145.517686  138.905771  132.467835  127.864705
# 92   133.241166  127.029427  119.142213  113.728725  108.457682  104.688882
# 51   130.134033  124.067150  116.363862  111.076615  105.928490  102.247578
# 102  159.672884  152.228891  142.777051  136.289663  129.972976  125.456540
#
# ...

# %% [markdown]
# #### Training a Linear Regression model by feeding this training data and making predictions

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# #### Evaluating using acccuracy and other metrics like MSE, MAE and R^2 score

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
#import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Assuming y_true and y_pred are your true and predicted values
# Replace these with your actual data
# Replace with your predicted values

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate R-squared
r2 = r2_score(y_test, y_pred)

# Create a DataFrame to display the results
metrics_data = {
    'Mean Squared Error': [mse],
    'Mean Absolute Error': [mae],
    'R-squared': [r2]
}

metrics_df = pd.DataFrame(metrics_data)
print(metrics_df)
# Out:
#    Mean Squared Error  Mean Absolute Error  R-squared
# 0        3.390607e-27         4.113668e-14        1.0

# %% [markdown]
# ### Creating a copy 'merged_df_3' of 'merged_df' which is the dataframe to work on

# %%
merged_df_3 = merged_df.copy()
merged_df_3
# Out:
#           city country    tier  COL_2022    COL_2021    COL_2020    COL_2019  \
# 0       Mumbai   India  Tier 1   613.890  575.396007  548.570891  514.510308
# 1        Delhi   India  Tier 1   333.990  313.047146  298.452804  279.921969
# 2      Kolkata   India  Tier 2   224.335  210.268066  200.465313  188.018489
# 3    Bangalore   India  Tier 1   310.190  290.739526  277.185171  259.974837
# 4      Chennai   India  Tier 1   260.190  243.874777  232.505270  218.069096
# ..         ...     ...     ...       ...         ...         ...         ...
# 108   Udhampur   India  Tier 2   159.440  149.442309  142.475269  133.629027
# 109  Dharmsala   India  Tier 2   209.750  196.597619  187.432185  175.794584
# 110  Udayagiri   India  Tier 3   136.850  128.268816  122.288889  114.696013
# 111  Cherukuru   India  Tier 3   116.230  108.941794  103.862898   97.414086
# 112   Tirupati   India  Tier 2   148.820  139.488237  132.985258  124.728248
#
# ...

# %% [markdown]
# ### Renaming all the columns/features from the format of 'COL_2022' to an integer value 2022

# %%
# Get the current column names
current_columns = merged_df_3.columns

# Extracting the year part and converting it into integers for relevant columns
new_columns = [col.split('_')[1] if col.startswith('COL_') else col for col in current_columns]

# Creating a dictionary to map current columns to new columns (with adjusted year names)
columns_mapping = dict(zip(current_columns, new_columns))

# Rename columns using the created mapping
merged_df_3 = merged_df_3.rename(columns=columns_mapping)

# %%
merged_df_3
# Out:
#           city country    tier     2022        2021        2020        2019  \
# 0       Mumbai   India  Tier 1  613.890  575.396007  548.570891  514.510308
# 1        Delhi   India  Tier 1  333.990  313.047146  298.452804  279.921969
# 2      Kolkata   India  Tier 2  224.335  210.268066  200.465313  188.018489
# 3    Bangalore   India  Tier 1  310.190  290.739526  277.185171  259.974837
# 4      Chennai   India  Tier 1  260.190  243.874777  232.505270  218.069096
# ..         ...     ...     ...      ...         ...         ...         ...
# 108   Udhampur   India  Tier 2  159.440  149.442309  142.475269  133.629027
# 109  Dharmsala   India  Tier 2  209.750  196.597619  187.432185  175.794584
# 110  Udayagiri   India  Tier 3  136.850  128.268816  122.288889  114.696013
# 111  Cherukuru   India  Tier 3  116.230  108.941794  103.862898   97.414086
# 112   Tirupati   India  Tier 2  148.820  139.488237  132.985258  124.728248
#
# ...

# %% [markdown]
# ## After trying and not being satisfied with the above approach of training a Linear Regression Model and predictin 2022 values using data from 2013-2021 as it is not in line with our objective of future prediction, we try other approaches

# %% [markdown]
# ### Working on Mumbai city, i.e. Row for Mumbai

# %% [markdown]
# #### Plotting a graph for Mumbai city for Year v/s COL(for that year)

# %%
### import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# Replace 'Mumbai' with the city name you want to plot
city_name_mum = 'Mumbai'

# Filter the DataFrame for the specified city
city_data_mum = merged_df_3.loc[merged_df_3['city'] == city_name_mum, '2022':'2012'].values.flatten()

# Years from 2012 to 2022 for x-axis
years = list(range(2022, 2011, -1))

# Plotting the curve/line graph
plt.figure(figsize=(10, 6))
plt.plot(years, city_data_mum, marker='o', linestyle='-')
plt.title(f'Cost of Living Trend in {city_name_mum} (2012 - 2023)')
plt.xlabel('Year')
plt.ylabel('Cost of Living')
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# #### Visualizing a linear regression line for the plot, i.e. plotting a linear line to find slope

# %%
# import numpy as np
# from scipy.stats import linregress
# import matplotlib.pyplot as plt

# # Assuming 'years' contains the x-axis values (from 2012 to 2022) and 'city_data' contains the y-axis values
# # Replace 'years' and 'city_data' with your actual data

# # Calculate the slope using linear regression
# slope, intercept, _, _, _ = linregress(years, city_data_mum)

# # Plotting the curve/line graph with the linear regression line
# plt.figure(figsize=(10, 6))
# plt.plot(years, city_data_mum, marker='o', linestyle='-', label='Cost of Living')
# plt.plot(years, slope * np.array(years) + intercept, color='red', linestyle='--', label='Linear Regression')
# plt.title(f'Cost of Living Trend in {city_name_mum} (2012 - 2022)')
# plt.xlabel('Year')
# plt.ylabel('Cost of Living')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()

# plt.show()

# print(f"The slope of the line (rate of change) is: {slope:.2f}")

import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

# Assuming 'years' contains the x-axis values (from 2012 to 2022) and 'city_data' contains the y-axis values
# Replace 'years' and 'city_data' with your actual data

# Calculate the slope using linear regression
slope, intercept, _, _, _ = linregress(years, city_data_mum)

# Plotting the curve/line graph with the linear regression line
plt.figure(figsize=(10, 6))
plt.plot(years, city_data_mum, marker='o', linestyle='-', label='Cost of Living')
plt.plot(years, slope * np.array(years) + intercept, color='red', linestyle='--', label='Linear Regression')
plt.title(f'Cost of Living Trend in {city_name_mum} (2012 - 2022)')
plt.xlabel('Year')
plt.ylabel('Cost of Living')
plt.legend()
plt.grid(True)

# Define the x-value where you want to annotate (e.g., 2018)
x_annotation = 2022

# Find the corresponding y-value for the given x-value (using linear regression equation)
y_annotation = slope * x_annotation + intercept

# Annotate the y-value at x=2018 on the plot
plt.annotate(f'Y={y_annotation:.2f}', (x_annotation, y_annotation), xytext=(x_annotation + 0.5, y_annotation + 10),
             arrowprops=dict(facecolor='black', arrowstyle='->'), fontsize=10)

plt.tight_layout()
plt.show()

print(f"The slope of the line (rate of change) is: {slope:.2f}")
# Out:
# The slope of the line (rate of change) is: 24.97

# %% [markdown]
# ##### Slope comes out to be 24.97

# %% [markdown]
# #### Plotting a 2nd degree polynomial curve(instead of linear curve) for 'Mumbai' datapoints and extending it for visualizing the curve for future years upto 2030, also marking the y(COL) value for x(year=2027) to know as per the graph what would be the future values

# %%
# Assuming 'years' contains the x-axis values (from 2012 to 2022) and 'city_data_2' contains the y-axis values
# Replace 'years' and 'city_data_2' with your actual data

# Fit a polynomial of degree 2 to the data
coefficients = np.polyfit(years, city_data_mum, 2)
poly_function = np.poly1d(coefficients)

# Extending the curve to predict values for years 2023 to 2030
future_years = np.arange(2022, 2040)  # New range for prediction
predicted_values = poly_function(future_years)

# Plotting the polynomial curve including the extended range
plt.figure(figsize=(10, 6))
plt.scatter(years, city_data_mum, label='Cost of Living (Existing Data)', color='blue')
plt.plot(years, poly_function(years), color='red', label='Polynomial Regression (Degree 2)')
plt.plot(future_years, predicted_values, color='green', linestyle='--', label='Extrapolation (2023 - 2030)')
plt.title(f'Cost of Living Trend in {city_name_mum} (2012 - 2040)')
plt.xlabel('Year')
plt.ylabel('Cost of Living')
plt.legend()
plt.grid(True)
plt.tight_layout()

# plt.show()

x_annotation = 2023
y_annotation = poly_function(x_annotation)

plt.annotate(f'({x_annotation}, {y_annotation:.2f})', (x_annotation, y_annotation),
             xytext=(-20, 20), textcoords='offset points',
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5'))

plt.show()

# Assuming 'years' contains the x-axis values (from 2012 to 2022) and 'city_data_2' contains the y-axis values
# Replace 'years' and 'city_data_2' with your actual data

# Fit a polynomial of degree 2 to the data
coefficients = np.polyfit(years, city_data_mum, 2)
poly_function = np.poly1d(coefficients)

# Calculate the derivative of the polynomial function
derivative_function = np.polyder(poly_function)

# Point at which to find the slope
x_point = 2027

# Calculate the slope (derivative) at x=2027
slope_at_x_2027 = derivative_function(x_point)

# Display the slope at x=2027
print(f"The slope at x=2027 is: {slope_at_x_2027:.2f}")
# Out:
# The slope at x=2027 is: 32.69

# %% [markdown]
# ### Performing the same steps on Vadodara city

# %% [markdown]
# #### Plotting a graph for Vadodara city for Year v/s COL(for that year)

# %%
city_name_vad = 'Vadodara'

# Filter the DataFrame for the specified city
city_data_vad = merged_df_3.loc[merged_df_3['city'] == city_name_vad, '2022':'2012'].values.flatten()

# Years from 2012 to 2022 for x-axis
years = list(range(2022, 2011, -1))

# Plotting the curve/line graph
plt.figure(figsize=(10, 6))
plt.plot(years, city_data_vad, marker='o', linestyle='-')
plt.title(f'Cost of Living Trend in {city_name_vad} (2012 - 2022)')
plt.xlabel('Year')
plt.ylabel('Cost of Living')
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# #### Visualizing a linear regression line for the plot, i.e. plotting a linear line to find slope

# %%
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

# Assuming 'years' contains the x-axis values (from 2012 to 2022) and 'city_data' contains the y-axis values
# Replace 'years' and 'city_data' with your actual data

# Calculate the slope using linear regression
slope, intercept, _, _, _ = linregress(years, city_data_vad)

# Plotting the curve/line graph with the linear regression line
plt.figure(figsize=(10, 6))
plt.plot(years, city_data_vad, marker='o', linestyle='-', label='Cost of Living')
plt.plot(years, slope * np.array(years) + intercept, color='red', linestyle='--', label='Linear Regression')
plt.title(f'Cost of Living Trend in {city_name_vad} (2012 - 2022)')
plt.xlabel('Year')
plt.ylabel('Cost of Living')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

print(f"The slope of the line (rate of change) is: {slope:.2f}")
# Out:
# The slope of the line (rate of change) is: 7.06

# %% [markdown]
# ##### Slope comes out to be 7.06

# %% [markdown]
# #### Plotting a 2nd degree polynomial curve(instead of linear curve) for 'Vadodara' datapoints and extending it for visualizing the curve for future years upto 2030, also marking the y(COL) value for x(year=2027) to know as per the graph what would be the future values

# %%
# Assuming 'years' contains the x-axis values (from 2012 to 2022) and 'city_data_2' contains the y-axis values
# Replace 'years' and 'city_data_2' with your actual data

# Fit a polynomial of degree 2 to the data
coefficients = np.polyfit(years, city_data_vad, 2)
poly_function = np.poly1d(coefficients)

# Extending the curve to predict values for years 2023 to 2030
future_years = np.arange(2022, 2050)  # New range for prediction
predicted_values = poly_function(future_years)

# Plotting the polynomial curve including the extended range
plt.figure(figsize=(10, 6))
plt.scatter(years, city_data_vad, label='Cost of Living (Existing Data)', color='blue')
plt.plot(years, poly_function(years), color='red', label='Polynomial Regression (Degree 2)')
plt.plot(future_years, predicted_values, color='green', linestyle='--', label='Extrapolation (2023 - 2030)')
plt.title(f'Cost of Living Trend in {city_name_vad} (2012 - 2030)')
plt.xlabel('Year')
plt.ylabel('Cost of Living')
plt.legend()
plt.grid(True)
plt.tight_layout()

x_annotation = 2027
y_annotation = poly_function(x_annotation)

plt.annotate(f'({x_annotation}, {y_annotation:.2f})', (x_annotation, y_annotation),
             xytext=(-20, 20), textcoords='offset points',
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5'))

plt.show()

# Assuming 'years' contains the x-axis values (from 2012 to 2022) and 'city_data_2' contains the y-axis values
# Replace 'years' and 'city_data_2' with your actual data

# Fit a polynomial of degree 2 to the data
coefficients = np.polyfit(years, city_data_vad, 2)
poly_function = np.poly1d(coefficients)

# Calculate the derivative of the polynomial function
derivative_function = np.polyder(poly_function)

# Point at which to find the slope
x_point = 2027

# Calculate the slope (derivative) at x=2027
slope_at_x_2027 = derivative_function(x_point)

# Display the slope at x=2027
print(f"The slope at x=2027 is: {slope_at_x_2027:.2f}")
# Out:
# The slope at x=2027 is: 9.25

# %% [markdown]
# ### Performing the same steps on Delhi city

# %% [markdown]
# #### Plotting a graph for Delhi city for Year v/s COL(for that year)

# %%
city_name_del = 'Delhi'

# Filter the DataFrame for the specified city
city_data_del = merged_df_3.loc[merged_df_3['city'] == city_name_del, '2022':'2012'].values.flatten()

# Years from 2012 to 2022 for x-axis
years = list(range(2022, 2011, -1))

# Plotting the curve/line graph
plt.figure(figsize=(10, 6))
plt.plot(years, city_data_del, marker='o', linestyle='-')
plt.title(f'Cost of Living Trend in {city_name_del} (2012 - 2022)')
plt.xlabel('Year')
plt.ylabel('Cost of Living')
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# #### Visualizing a linear regression line for the plot, i.e. plotting a linear line to find slope

# %%
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

# Assuming 'years' contains the x-axis values (from 2012 to 2022) and 'city_data' contains the y-axis values
# Replace 'years' and 'city_data' with your actual data

# Calculate the slope using linear regression
slope, intercept, _, _, _ = linregress(years, city_data_del)

# Plotting the curve/line graph with the linear regression line
plt.figure(figsize=(10, 6))
plt.plot(years, city_data_del, marker='o', linestyle='-', label='Cost of Living')
plt.plot(years, slope * np.array(years) + intercept, color='red', linestyle='--', label='Linear Regression')
plt.title(f'Cost of Living Trend in {city_name_del} (2012 - 2022)')
plt.xlabel('Year')
plt.ylabel('Cost of Living')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

print(f"The slope of the line (rate of change) is: {slope:.2f}")
# Out:
# The slope of the line (rate of change) is: 13.59

# %% [markdown]
# ##### Slope comes out to be 13.59

# %% [markdown]
# #### Plotting a 2nd degree polynomial curve(instead of linear curve) for 'Delhi' datapoints and extending it for visualizing the curve for future years upto 2030, also marking the y(COL) value for x(year=2027) to know as per the graph what would be the future values

# %%
# Assuming 'years' contains the x-axis values (from 2012 to 2022) and 'city_data_2' contains the y-axis values
# Replace 'years' and 'city_data_2' with your actual data

# Fit a polynomial of degree 2 to the data
coefficients = np.polyfit(years, city_data_del, 2)
poly_function = np.poly1d(coefficients)

# Extending the curve to predict values for years 2023 to 2030
future_years = np.arange(2022, 2050)  # New range for prediction
predicted_values = poly_function(future_years)

# Plotting the polynomial curve including the extended range
plt.figure(figsize=(10, 6))
plt.scatter(years, city_data_del, label='Cost of Living (Existing Data)', color='blue')
plt.plot(years, poly_function(years), color='red', label='Polynomial Regression (Degree 2)')
plt.plot(future_years, predicted_values, color='green', linestyle='--', label='Extrapolation (2023 - 2030)')
plt.title(f'Cost of Living Trend in {city_name_del} (2012 - 2030)')
plt.xlabel('Year')
plt.ylabel('Cost of Living')
plt.legend()
plt.grid(True)
plt.tight_layout()

x_annotation = 2027
y_annotation = poly_function(x_annotation)

plt.annotate(f'({x_annotation}, {y_annotation:.2f})', (x_annotation, y_annotation),
             xytext=(-20, 20), textcoords='offset points',
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5'))

plt.show()

# Assuming 'years' contains the x-axis values (from 2012 to 2022) and 'city_data_2' contains the y-axis values
# Replace 'years' and 'city_data_2' with your actual data

# Fit a polynomial of degree 2 to the data
coefficients = np.polyfit(years, city_data_del, 2)
poly_function = np.poly1d(coefficients)

# Calculate the derivative of the polynomial function
derivative_function = np.polyder(poly_function)

# Point at which to find the slope
x_point = 2027

# Calculate the slope (derivative) at x=2027
slope_at_x_2027 = derivative_function(x_point)

# Display the slope at x=2027
print(f"The slope at x=2027 is: {slope_at_x_2027:.2f}")
# Out:
# The slope at x=2027 is: 17.79

# %% [markdown]
# ## Trying to train and predict the COL values using Polynomial Regression

# %% [markdown]
# #### Duplicating from merged_df_3 to merged_df_4 to make sure I have merged_df_3 as backup

# %%
merged_df_3
# Out:
#           city country    tier     2022        2021        2020        2019  \
# 0       Mumbai   India  Tier 1  613.890  575.396007  548.570891  514.510308
# 1        Delhi   India  Tier 1  333.990  313.047146  298.452804  279.921969
# 2      Kolkata   India  Tier 2  224.335  210.268066  200.465313  188.018489
# 3    Bangalore   India  Tier 1  310.190  290.739526  277.185171  259.974837
# 4      Chennai   India  Tier 1  260.190  243.874777  232.505270  218.069096
# ..         ...     ...     ...      ...         ...         ...         ...
# 108   Udhampur   India  Tier 2  159.440  149.442309  142.475269  133.629027
# 109  Dharmsala   India  Tier 2  209.750  196.597619  187.432185  175.794584
# 110  Udayagiri   India  Tier 3  136.850  128.268816  122.288889  114.696013
# 111  Cherukuru   India  Tier 3  116.230  108.941794  103.862898   97.414086
# 112   Tirupati   India  Tier 2  148.820  139.488237  132.985258  124.728248
#
# ...

# %%
merged_df_4 = merged_df_3.copy()
merged_df_4
# Out:
#           city country    tier     2022        2021        2020        2019  \
# 0       Mumbai   India  Tier 1  613.890  575.396007  548.570891  514.510308
# 1        Delhi   India  Tier 1  333.990  313.047146  298.452804  279.921969
# 2      Kolkata   India  Tier 2  224.335  210.268066  200.465313  188.018489
# 3    Bangalore   India  Tier 1  310.190  290.739526  277.185171  259.974837
# 4      Chennai   India  Tier 1  260.190  243.874777  232.505270  218.069096
# ..         ...     ...     ...      ...         ...         ...         ...
# 108   Udhampur   India  Tier 2  159.440  149.442309  142.475269  133.629027
# 109  Dharmsala   India  Tier 2  209.750  196.597619  187.432185  175.794584
# 110  Udayagiri   India  Tier 3  136.850  128.268816  122.288889  114.696013
# 111  Cherukuru   India  Tier 3  116.230  108.941794  103.862898   97.414086
# 112   Tirupati   India  Tier 2  148.820  139.488237  132.985258  124.728248
#
# ...

# %%
# Dropping 'country' and 'tier' columns
merged_df_4.drop(['country', 'tier'], axis=1, inplace=True)

# Encode 'city' column
# from sklearn.preprocessing import LabelEncoder
# label_encoder = LabelEncoder()
# merged_df_4['city_encoded'] = label_encoder.fit_transform(merged_df_3['city'])
# merged_df_4.drop('city', axis=1, inplace=True)

# %%
merged_df_4
# Out:
#           city     2022        2021        2020        2019        2018  \
# 0       Mumbai  613.890  575.396007  548.570891  514.510308  491.132406
# 1        Delhi  333.990  313.047146  298.452804  279.921969  267.203102
# 2      Kolkata  224.335  210.268066  200.465313  188.018489  179.475457
# 3    Bangalore  310.190  290.739526  277.185171  259.974837  248.162311
# 4      Chennai  260.190  243.874777  232.505270  218.069096  208.160649
# ..         ...      ...         ...         ...         ...         ...
# 108   Udhampur  159.440  149.442309  142.475269  133.629027  127.557300
# 109  Dharmsala  209.750  196.597619  187.432185  175.794584  167.806972
# 110  Udayagiri  136.850  128.268816  122.288889  114.696013  109.484549
# 111  Cherukuru  116.230  108.941794  103.862898   97.414086   92.987863
# 112   Tirupati  148.820  139.488237  132.985258  124.728248  119.060947
#
#            2017        2016        2015        2014        2013        2012
# ...

# %% [markdown]
# #### Giving inputs from user(me) for the desired city and year and using the 2nd degree polynomial curve, printing the cost of living value for any future year for any city

# %%
city_name = input("Enter the city name: ")
prediction_year = int(input("Enter year you want to predict for: "))
# Out:
# Enter the city name:  Mumbai
# Enter year you want to predict for:  2030

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to predict cost for a given city and year
def predict_cost_of_living(years, city_data, city_name, prediction_year):
    coefficients = np.polyfit(years, city_data, 2)
    poly_function = np.poly1d(coefficients)

    # Plotting the polynomial curve
    plt.figure(figsize=(10, 6))
    plt.scatter(years, city_data, label='Cost of Living (Existing Data)', color='blue')
    plt.plot(years, poly_function(years), color='red', label='Polynomial Regression (Degree 2)')

    # Extending the curve to predict values for future years
    future_years = np.arange(2022, 2050)
    predicted_values = poly_function(future_years)
    plt.plot(future_years, predicted_values, color='green', linestyle='--', label=f'Extrapolation ({max(years) + 1} - {prediction_year})')

    plt.title(f'Cost of Living Trend in {city_name} (2012 - {prediction_year + 10})')
    plt.xlabel('Year')
    plt.ylabel('Cost of Living')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    # Annotation for a specific year
    x_annotation = prediction_year
    y_annotation = poly_function(x_annotation)
    plt.annotate(f'({x_annotation}, {y_annotation:.2f})', (x_annotation, y_annotation),
                 xytext=(-20, 20), textcoords='offset points',
                 arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5'))

    plt.show()

    # Calculate the derivative of the polynomial function
    derivative_function = np.polyder(poly_function)

    # Calculate the slope (derivative) at the given prediction year
    slope_at_prediction_year = derivative_function(prediction_year)
    print(f"The slope at {prediction_year} for {city_name} is: {slope_at_prediction_year:.2f}")

    # Return the predicted cost for the specified year
    return poly_function(prediction_year)

# Sample data (Replace with actual data)
years = list(range(2022, 2011, -1)) # Replace with actual years data
city_data = merged_df_4.loc[merged_df_4['city'] == city_name, '2022':'2012'].values.flatten() # Replace with actual cost data
#city_name = 'Mumbai'

# Example usage
#prediction_year = 2034  # Replace with the year you want to predict
predicted_cost = predict_cost_of_living(years, city_data, city_name, prediction_year)
print(f"The predicted cost of living in {city_name} for the year {prediction_year} is: {predicted_cost:.2f}")
# Out:
# The slope at 2030 for Mumbai is: 35.01
# The predicted cost of living in Mumbai for the year 2030 is: 861.40

# %%
# import os
# print(os.getcwd())

# %%
# with open('model.pkl', 'wb') as model_file:
#     pickle.dump(predict_cost_of_living, model_file)

# %% [markdown]
# #### Trying a slightly different approach by instead of backtracking to 2012, we try by backtracking to 2005, 2010 and 1999 to see the best suit

# %%
merged_df_6 = merged_df_3.copy()
merged_df_6
# Out:
#           city country    tier     2022        2021        2020        2019  \
# 0       Mumbai   India  Tier 1  613.890  575.396007  548.570891  514.510308
# 1        Delhi   India  Tier 1  333.990  313.047146  298.452804  279.921969
# 2      Kolkata   India  Tier 2  224.335  210.268066  200.465313  188.018489
# 3    Bangalore   India  Tier 1  310.190  290.739526  277.185171  259.974837
# 4      Chennai   India  Tier 1  260.190  243.874777  232.505270  218.069096
# ..         ...     ...     ...      ...         ...         ...         ...
# 108   Udhampur   India  Tier 2  159.440  149.442309  142.475269  133.629027
# 109  Dharmsala   India  Tier 2  209.750  196.597619  187.432185  175.794584
# 110  Udayagiri   India  Tier 3  136.850  128.268816  122.288889  114.696013
# 111  Cherukuru   India  Tier 3  116.230  108.941794  103.862898   97.414086
# 112   Tirupati   India  Tier 2  148.820  139.488237  132.985258  124.728248
#
# ...

# %%
merged_df_6 = pd.merge(df_india_final, df_inflation_india[['country', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011']], on='country', how='left')

# Rename the inflation rate column for clarity
merged_df_6.rename(columns={'2022': 'inflation_2022', '2021':'inflation_2021','2020':'inflation_2020', '2019':'inflation_2019', '2018':'inflation_2018', '2017':'inflation_2017', '2016':'inflation_2016', '2015':'inflation_2015', '2014':'inflation_2014', '2013':'inflation_2013', '2012':'inflation_2012', '2011':'inflation_2011'}, inplace=True)

# Calculate COL_2021 based on the formula
merged_df_6['COL_2021'] = merged_df_6['COL_2022'] / (1 +( merged_df_6['inflation_2022'])/100)
merged_df_6['COL_2020'] = merged_df_6['COL_2021'] / (1 +( merged_df_6['inflation_2021'])/100)
merged_df_6['COL_2019'] = merged_df_6['COL_2020'] / (1 +( merged_df_6['inflation_2020'])/100)
merged_df_6['COL_2018'] = merged_df_6['COL_2019'] / (1 +( merged_df_6['inflation_2019'])/100)
merged_df_6['COL_2017'] = merged_df_6['COL_2018'] / (1 +( merged_df_6['inflation_2018'])/100)
merged_df_6['COL_2016'] = merged_df_6['COL_2017'] / (1 +( merged_df_6['inflation_2017'])/100)
merged_df_6['COL_2015'] = merged_df_6['COL_2016'] / (1 +( merged_df_6['inflation_2016'])/100)
merged_df_6['COL_2014'] = merged_df_6['COL_2015'] / (1 +( merged_df_6['inflation_2015'])/100)
merged_df_6['COL_2013'] = merged_df_6['COL_2014'] / (1 +( merged_df_6['inflation_2014'])/100)
merged_df_6['COL_2012'] = merged_df_6['COL_2013'] / (1 +( merged_df_6['inflation_2013'])/100)
merged_df_6['COL_2011'] = merged_df_6['COL_2012'] / (1 +( merged_df_6['inflation_2012'])/100)
merged_df_6['COL_2010'] = merged_df_6['COL_2011'] / (1 +( merged_df_6['inflation_2011'])/100)

# Display or use the updated dataframe with 'COL_2021'
merged_df_6
# Out:
#           city country    tier  COL_2022  inflation_2022  inflation_2021  \
# 0       Mumbai   India  Tier 1   613.890            6.69            4.89
# 1        Delhi   India  Tier 1   333.990            6.69            4.89
# 2      Kolkata   India  Tier 2   224.335            6.69            4.89
# 3    Bangalore   India  Tier 1   310.190            6.69            4.89
# 4      Chennai   India  Tier 1   260.190            6.69            4.89
# ..         ...     ...     ...       ...             ...             ...
# 108   Udhampur   India  Tier 2   159.440            6.69            4.89
# 109  Dharmsala   India  Tier 2   209.750            6.69            4.89
# 110  Udayagiri   India  Tier 3   136.850            6.69            4.89
# 111  Cherukuru   India  Tier 3   116.230            6.69            4.89
# 112   Tirupati   India  Tier 2   148.820            6.69            4.89
#
#      inflation_2020  inflation_2019  inflation_2018  inflation_2017  ...  \
# ...

# %%
merged_df_6.drop(columns = ['inflation_2022', 'inflation_2021', 'inflation_2020', 'inflation_2019', 'inflation_2018', 'inflation_2017', 'inflation_2016', 'inflation_2015', 'inflation_2014', 'inflation_2013', 'inflation_2012', 'inflation_2011'], axis = 1, inplace=True)

# %%
merged_df_6.drop('country', axis=1, inplace=True)
merged_df_6.drop('tier', axis=1, inplace=True)
merged_df_6
# Out:
#           city  COL_2022    COL_2021    COL_2020    COL_2019    COL_2018  \
# 0       Mumbai   613.890  575.396007  548.570891  514.510308  491.132406
# 1        Delhi   333.990  313.047146  298.452804  279.921969  267.203102
# 2      Kolkata   224.335  210.268066  200.465313  188.018489  179.475457
# 3    Bangalore   310.190  290.739526  277.185171  259.974837  248.162311
# 4      Chennai   260.190  243.874777  232.505270  218.069096  208.160649
# ..         ...       ...         ...         ...         ...         ...
# 108   Udhampur   159.440  149.442309  142.475269  133.629027  127.557300
# 109  Dharmsala   209.750  196.597619  187.432185  175.794584  167.806972
# 110  Udayagiri   136.850  128.268816  122.288889  114.696013  109.484549
# 111  Cherukuru   116.230  108.941794  103.862898   97.414086   92.987863
# 112   Tirupati   148.820  139.488237  132.985258  124.728248  119.060947
#
#        COL_2017    COL_2016    COL_2015    COL_2014    COL_2013    COL_2012  \
# ...

# %%
# Get the current column names
current_columns = merged_df_6.columns

# Extracting the year part and converting it into integers for relevant columns
new_columns = [col.split('_')[1] if col.startswith('COL_') else col for col in current_columns]

# Creating a dictionary to map current columns to new columns (with adjusted year names)
columns_mapping = dict(zip(current_columns, new_columns))

# Rename columns using the created mapping
merged_df_6 = merged_df_6.rename(columns=columns_mapping)

# %%
merged_df_6
# Out:
#           city     2022        2021        2020        2019        2018  \
# 0       Mumbai  613.890  575.396007  548.570891  514.510308  491.132406
# 1        Delhi  333.990  313.047146  298.452804  279.921969  267.203102
# 2      Kolkata  224.335  210.268066  200.465313  188.018489  179.475457
# 3    Bangalore  310.190  290.739526  277.185171  259.974837  248.162311
# 4      Chennai  260.190  243.874777  232.505270  218.069096  208.160649
# ..         ...      ...         ...         ...         ...         ...
# 108   Udhampur  159.440  149.442309  142.475269  133.629027  127.557300
# 109  Dharmsala  209.750  196.597619  187.432185  175.794584  167.806972
# 110  Udayagiri  136.850  128.268816  122.288889  114.696013  109.484549
# 111  Cherukuru  116.230  108.941794  103.862898   97.414086   92.987863
# 112   Tirupati  148.820  139.488237  132.985258  124.728248  119.060947
#
#            2017        2016        2015        2014        2013        2012  \
# ...

# %%
# # Specify the path and name of the Excel file
# excel_file_path = 'india_subset.xlsx'

# # Save the DataFrame to a new sheet in the Excel file
# merged_df_6.to_excel(excel_file_path, sheet_name='India_Subset', index=False)

# print(f'DataFrame saved to {excel_file_path}')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to predict cost for a given city and year
def predict_cost_of_living(years, city_data, city_name, prediction_year):
    coefficients = np.polyfit(years, city_data, 2)
    poly_function = np.poly1d(coefficients)

    # Plotting the polynomial curve
    plt.figure(figsize=(10, 6))
    plt.scatter(years, city_data, label='Cost of Living (Existing Data)', color='blue')
    plt.plot(years, poly_function(years), color='red', label='Polynomial Regression (Degree 2)')

    # Extending the curve to predict values for future years
    future_years = np.arange(2022, 2050)
    predicted_values = poly_function(future_years)
    plt.plot(future_years, predicted_values, color='green', linestyle='--', label=f'Extrapolation ({max(years) + 1} - {prediction_year})')

    plt.title(f'Cost of Living Trend in {city_name} (2012 - {prediction_year + 10})')
    plt.xlabel('Year')
    plt.ylabel('Cost of Living')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    # Annotation for a specific year
    x_annotation = prediction_year
    y_annotation = poly_function(x_annotation)
    plt.annotate(f'({x_annotation}, {y_annotation:.2f})', (x_annotation, y_annotation),
                 xytext=(-20, 20), textcoords='offset points',
                 arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5'))

    plt.show()

    # Calculate the derivative of the polynomial function
    derivative_function = np.polyder(poly_function)

    # Calculate the slope (derivative) at the given prediction year
    slope_at_prediction_year = derivative_function(prediction_year)
    print(f"The slope at {prediction_year} for {city_name} is: {slope_at_prediction_year:.2f}")

    # Return the predicted cost for the specified year
    return poly_function(prediction_year)

# Sample data (Replace with actual data)
years = list(range(2022, 2009, -1)) # Replace with actual years data
city_data = merged_df_6.loc[merged_df_6['city'] == city_name, '2022':'2010'].values.flatten() # Replace with actual cost data
#city_name = 'Mumbai'

# Example usage
#prediction_year = 2034  # Replace with the year you want to predict
predicted_cost = predict_cost_of_living(years, city_data, city_name, prediction_year)
print(f"The predicted cost of living in {city_name} for the year {prediction_year} is: {predicted_cost:.2f}")
# Out:
# The slope at 2030 for Mumbai is: 25.42
# The predicted cost of living in Mumbai for the year 2030 is: 806.02

# %% [markdown]
# ### After trying 2012, 2010, 2005 and 1999, the outcomes seen were for Mumbai in 2030 the COL values were 861, 806, 835 and 935
# ### Out of these, it is seen the most reliable and feasible comes out to be 2012 as we approached initially so that is fixed

# %% [markdown]
# # Final work done upto 04/02/2024

# %% [markdown]
# ## To find accuracy of prediction with this approach(training using 2012-2022 data and predicting future), as we have proper data of 2022, we will be training model with different years(for eg: 2000-2010, 2010-2020, 1980-2015 etc)

# %% [markdown]
# ### Revising the final dataframes

# %%
df_india_final
# Out:
#            city country    tier  COL_2022
# 3        Mumbai   India  Tier 1   613.890
# 4         Delhi   India  Tier 1   333.990
# 16      Kolkata   India  Tier 2   224.335
# 24    Bangalore   India  Tier 1   310.190
# 26      Chennai   India  Tier 1   260.190
# ...         ...     ...     ...       ...
# 4225   Udhampur   India  Tier 2   159.440
# 4593  Dharmsala   India  Tier 2   209.750
# 4677  Udayagiri   India  Tier 3   136.850
# 4895  Cherukuru   India  Tier 3   116.230
# 4945   Tirupati   India  Tier 2   148.820
#
# [113 rows x 4 columns]

# %%
df_inflation_india
# Out:
#    Country Code  IMF Country Code country Indicator Type  \
# 79          IND             534.0   India      Inflation
#
#                           Series Name  1970  1971  1972   1973  1974  ...  \
# 79  Headline Consumer Price Inflation   5.1  3.08  6.44  16.94  28.6  ...
#
#     2015  2016  2017  2018  2019  2020  2021  2022                      Note  \
# 79  5.87  4.94   3.6  4.86  4.76  6.62  4.89  6.69  Annual average inflation
#
#     Column1
# 79      NaN
#
# [1 rows x 60 columns]

# %%
df_inflation_india.isnull().sum()
# Out:
# Country Code        0
# IMF Country Code    0
# country             0
# Indicator Type      0
# Series Name         0
# 1970                0
# 1971                0
# 1972                0
# 1973                0
# 1974                0
# 1975                0
# 1976                0
# 1977                0
# 1978                0
# 1979                0
# 1980                0
# 1981                0
# 1982                0
# 1983                0
# 1984                0
# 1985                0
# 1986                0
# 1987                0
# 1988                0
# 1989                0
# 1990                0
# 1991                0
# 1992                0
# 1993                0
# 1994                0
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0
# 2000                0
# 2001                0
# 2002                0
# 2003                0
# 2004                0
# 2005                0
# ...

# %% [markdown]
# ### Approach 1

# %% [markdown]
# #### Making a new dataframe merged_df_7 which has COL values back to year 2000 and dropping unwanted columns

# %%
# Replace 'merged_df_6' with 'merged_df_7' in the code
merged_df_7 = pd.merge(df_india_final, df_inflation_india[['country', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000']], on='country', how='left')

# Rename the inflation rate column for clarity
merged_df_7.rename(columns={'2022': 'inflation_2022', '2021':'inflation_2021','2020':'inflation_2020', '2019':'inflation_2019', '2018':'inflation_2018', '2017':'inflation_2017', '2016':'inflation_2016', '2015':'inflation_2015', '2014':'inflation_2014', '2013':'inflation_2013', '2012':'inflation_2012', '2011':'inflation_2011', '2010':'inflation_2010', '2009':'inflation_2009', '2008':'inflation_2008', '2007':'inflation_2007', '2006':'inflation_2006', '2005':'inflation_2005', '2004':'inflation_2004', '2003':'inflation_2003', '2002':'inflation_2002', '2001':'inflation_2001', '2000':'inflation_2000', '1999':'inflation_1999'}, inplace=True)

# Calculate COL values based on the formula
merged_df_7['COL_2021'] = merged_df_7['COL_2022'] / (1 + (merged_df_7['inflation_2022']) / 100)
merged_df_7['COL_2020'] = merged_df_7['COL_2021'] / (1 + (merged_df_7['inflation_2021']) / 100)
merged_df_7['COL_2019'] = merged_df_7['COL_2020'] / (1 + (merged_df_7['inflation_2020']) / 100)
merged_df_7['COL_2018'] = merged_df_7['COL_2019'] / (1 + (merged_df_7['inflation_2019']) / 100)
merged_df_7['COL_2017'] = merged_df_7['COL_2018'] / (1 + (merged_df_7['inflation_2018']) / 100)
merged_df_7['COL_2016'] = merged_df_7['COL_2017'] / (1 + (merged_df_7['inflation_2017']) / 100)
merged_df_7['COL_2015'] = merged_df_7['COL_2016'] / (1 + (merged_df_7['inflation_2016']) / 100)
merged_df_7['COL_2014'] = merged_df_7['COL_2015'] / (1 + (merged_df_7['inflation_2015']) / 100)
merged_df_7['COL_2013'] = merged_df_7['COL_2014'] / (1 + (merged_df_7['inflation_2014']) / 100)
merged_df_7['COL_2012'] = merged_df_7['COL_2013'] / (1 + (merged_df_7['inflation_2013']) / 100)
merged_df_7['COL_2011'] = merged_df_7['COL_2012'] / (1 + (merged_df_7['inflation_2012']) / 100)
merged_df_7['COL_2010'] = merged_df_7['COL_2011'] / (1 + (merged_df_7['inflation_2011']) / 100)
merged_df_7['COL_2009'] = merged_df_7['COL_2010'] / (1 + (merged_df_7['inflation_2010']) / 100)
merged_df_7['COL_2008'] = merged_df_7['COL_2009'] / (1 + (merged_df_7['inflation_2009']) / 100)
merged_df_7['COL_2007'] = merged_df_7['COL_2008'] / (1 + (merged_df_7['inflation_2008']) / 100)
merged_df_7['COL_2006'] = merged_df_7['COL_2007'] / (1 + (merged_df_7['inflation_2007']) / 100)
merged_df_7['COL_2005'] = merged_df_7['COL_2006'] / (1 + (merged_df_7['inflation_2006']) / 100)
merged_df_7['COL_2004'] = merged_df_7['COL_2005'] / (1 + (merged_df_7['inflation_2005']) / 100)
merged_df_7['COL_2003'] = merged_df_7['COL_2004'] / (1 + (merged_df_7['inflation_2004']) / 100)
merged_df_7['COL_2002'] = merged_df_7['COL_2003'] / (1 + (merged_df_7['inflation_2003']) / 100)
merged_df_7['COL_2001'] = merged_df_7['COL_2002'] / (1 + (merged_df_7['inflation_2002']) / 100)
merged_df_7['COL_2000'] = merged_df_7['COL_2001'] / (1 + (merged_df_7['inflation_2001']) / 100)

# Display or use the updated dataframe with 'COL_2021'
merged_df_7
# Out:
#           city country    tier  COL_2022  inflation_2022  inflation_2021  \
# 0       Mumbai   India  Tier 1   613.890            6.69            4.89
# 1        Delhi   India  Tier 1   333.990            6.69            4.89
# 2      Kolkata   India  Tier 2   224.335            6.69            4.89
# 3    Bangalore   India  Tier 1   310.190            6.69            4.89
# 4      Chennai   India  Tier 1   260.190            6.69            4.89
# ..         ...     ...     ...       ...             ...             ...
# 108   Udhampur   India  Tier 2   159.440            6.69            4.89
# 109  Dharmsala   India  Tier 2   209.750            6.69            4.89
# 110  Udayagiri   India  Tier 3   136.850            6.69            4.89
# 111  Cherukuru   India  Tier 3   116.230            6.69            4.89
# 112   Tirupati   India  Tier 2   148.820            6.69            4.89
#
#      inflation_2020  inflation_2019  inflation_2018  inflation_2017  ...  \
# ...

# %%
merged_df_7.drop(columns = ['inflation_2022', 'inflation_2021', 'inflation_2020', 'inflation_2019', 'inflation_2018', 'inflation_2017', 'inflation_2016', 'inflation_2015', 'inflation_2014', 'inflation_2013', 'inflation_2012', 'inflation_2011', 'inflation_2010', 'inflation_2009', 'inflation_2008', 'inflation_2007', 'inflation_2006', 'inflation_2005', 'inflation_2004', 'inflation_2003', 'inflation_2002', 'inflation_2001'], axis = 1, inplace=True)

# %%
merged_df_7.drop('country', axis=1, inplace=True)
merged_df_7.drop('tier', axis=1, inplace=True)
merged_df_7.drop('inflation_2000', axis=1, inplace=True)
merged_df_7
# Out:
#           city  COL_2022    COL_2021    COL_2020    COL_2019    COL_2018  \
# 0       Mumbai   613.890  575.396007  548.570891  514.510308  491.132406
# 1        Delhi   333.990  313.047146  298.452804  279.921969  267.203102
# 2      Kolkata   224.335  210.268066  200.465313  188.018489  179.475457
# 3    Bangalore   310.190  290.739526  277.185171  259.974837  248.162311
# 4      Chennai   260.190  243.874777  232.505270  218.069096  208.160649
# ..         ...       ...         ...         ...         ...         ...
# 108   Udhampur   159.440  149.442309  142.475269  133.629027  127.557300
# 109  Dharmsala   209.750  196.597619  187.432185  175.794584  167.806972
# 110  Udayagiri   136.850  128.268816  122.288889  114.696013  109.484549
# 111  Cherukuru   116.230  108.941794  103.862898   97.414086   92.987863
# 112   Tirupati   148.820  139.488237  132.985258  124.728248  119.060947
#
#        COL_2017    COL_2016    COL_2015    COL_2014  ...    COL_2009  \
# ...

# %%
# Get the current column names
current_columns = merged_df_7.columns

# Extracting the year part and converting it into integers for relevant columns
new_columns = [col.split('_')[1] if col.startswith('COL_') else col for col in current_columns]

# Creating a dictionary to map current columns to new columns (with adjusted year names)
columns_mapping = dict(zip(current_columns, new_columns))

# Rename columns using the created mapping
merged_df_7 = merged_df_7.rename(columns=columns_mapping)

# %%
merged_df_7[merged_df_7['city']=='Delhi']
# Out:
#     city    2022        2021        2020        2019        2018        2017  \
# 1  Delhi  333.99  313.047146  298.452804  279.921969  267.203102  254.818903
#
#          2016        2015        2014  ...        2009        2008  \
# 1  245.964192  234.385546  221.389956  ...  140.845263  127.024949
#
#          2007        2006        2005       2004       2003       2002  \
# 1  117.235762  110.215063  104.173027  99.926165  96.295813  92.761596
#
#         2001       2000
# 1  88.937293  85.697912
#
# [1 rows x 24 columns]

# %% [markdown]
# #### Using the polynomial regression along with extrapolation approach to predict

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to predict cost for a given city and year
def predict_cost_of_living(years, city_data, city_name, prediction_year):
    coefficients = np.polyfit(years, city_data, 2)
    poly_function = np.poly1d(coefficients)

    # Plotting the polynomial curve
    plt.figure(figsize=(10, 6))
    plt.scatter(years, city_data, label='Cost of Living (Existing Data)', color='blue')
    plt.plot(years, poly_function(years), color='red', label='Polynomial Regression (Degree 2)')

    # Extending the curve to predict values for future years
    future_years = np.arange(2000, 2035)
    predicted_values = poly_function(future_years)
    plt.plot(future_years, predicted_values, color='green', linestyle='--', label=f'Extrapolation ({max(years) + 1} - {prediction_year})')

    plt.title(f'Cost of Living Trend in {city_name} (2012 - {prediction_year + 10})')
    plt.xlabel('Year')
    plt.ylabel('Cost of Living')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    # Annotation for a specific year
    x_annotation = prediction_year
    y_annotation = poly_function(x_annotation)
    plt.annotate(f'({x_annotation}, {y_annotation:.2f})', (x_annotation, y_annotation),
                 xytext=(-20, 20), textcoords='offset points',
                 arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5'))

    plt.show()

    # Calculate the derivative of the polynomial function
    derivative_function = np.polyder(poly_function)

    # Calculate the slope (derivative) at the given prediction year
    slope_at_prediction_year = derivative_function(prediction_year)
    print(f"The slope at {prediction_year} for {city_name} is: {slope_at_prediction_year:.2f}")

    # Return the predicted cost for the specified year
    return poly_function(prediction_year)

# # Sample data (Replace with actual data)
# years = list(range(2010, 2000, -1)) # Replace with actual years data
# city_data = merged_df_7.loc[merged_df_7['city'] == city_name, '2010':'2000'].values.flatten() # Replace with actual cost data
# #city_name = 'Mumbai'

# # Example usage
# #prediction_year = 2034  # Replace with the year you want to predict
# predicted_cost = predict_cost_of_living(years, city_data, city_name, prediction_year)
# print(f"The predicted cost of living in {city_name} for the year {prediction_year} is: {predicted_cost:.2f}")

city_name = 'Mumbai'
#years = np.array([2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000])  # Ensure this array has the correct length
years = list(range(2021, 2000, -1))
city_data = merged_df_7.loc[merged_df_7['city'] == city_name, '2021':'2001'].values.flatten()
prediction_year = 2030  # Replace with the year you want to predict
predicted_cost = predict_cost_of_living(years, city_data, city_name, prediction_year)
print(f"The predicted cost of living in {city_name} for the year {prediction_year} is: {predicted_cost:.2f}")
# Out:
# The slope at 2030 for Mumbai is: 41.64
# The predicted cost of living in Mumbai for the year 2030 is: 920.15

# %% [markdown]
# ### Approach 2

# %% [markdown]
# #### Printing dataframes

# %%
pd.set_option('display.max_columns', None)
df_inflation_india
# Out:
#    Country Code  IMF Country Code country Indicator Type  \
# 79          IND             534.0   India      Inflation
#
#                           Series Name  1970  1971  1972   1973  1974  1975  \
# 79  Headline Consumer Price Inflation   5.1  3.08  6.44  16.94  28.6  5.75
#
#     1976  1977  1978  1979   1980   1981  1982   1983  1984  1985  1986  1987  \
# 79 -7.63  8.31  2.52  6.28  11.35  13.11  7.89  11.87  8.32  5.56  8.73   8.8
#
#     1988  1989  1990   1991   1992  1993   1994   1995  1996  1997   1998  \
# 79  9.38  7.07  8.97  13.87  11.79  6.33  10.25  10.22  8.98  7.16  13.23
#
#     1999  2000  2001  2002  2003  2004  2005  2006  2007  2008   2009   2010  \
# 79  4.67  4.01  3.78   4.3  3.81  3.77  4.25   5.8  6.37  8.35  10.88  11.99
#
#     2011  2012   2013  2014  2015  2016  2017  2018  2019  2020  2021  2022  \
# 79  8.86  9.31  10.91  6.35  5.87  4.94   3.6  4.86  4.76  6.62  4.89  6.69
#
#                         Note Column1
# ...

# %%
df_india_final
# Out:
#            city country    tier  COL_2022
# 3        Mumbai   India  Tier 1   613.890
# 4         Delhi   India  Tier 1   333.990
# 16      Kolkata   India  Tier 2   224.335
# 24    Bangalore   India  Tier 1   310.190
# 26      Chennai   India  Tier 1   260.190
# ...         ...     ...     ...       ...
# 4225   Udhampur   India  Tier 2   159.440
# 4593  Dharmsala   India  Tier 2   209.750
# 4677  Udayagiri   India  Tier 3   136.850
# 4895  Cherukuru   India  Tier 3   116.230
# 4945   Tirupati   India  Tier 2   148.820
#
# [113 rows x 4 columns]

# %% [markdown]
# #### Making a new dataframe merged_df_8 and Backtracking upto year 1980 for best understanding and measuring accuracy

# %%
# Replace 'merged_df_7' with 'merged_df_8' in the code
merged_df_8 = pd.merge(df_india_final, df_inflation_india[['country', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982', '1981', '1980']], on='country', how='left')

# Rename the inflation rate column for clarity
merged_df_8.rename(columns={'2022': 'inflation_2022', '2021':'inflation_2021','2020':'inflation_2020', '2019':'inflation_2019', '2018':'inflation_2018', '2017':'inflation_2017', '2016':'inflation_2016', '2015':'inflation_2015', '2014':'inflation_2014', '2013':'inflation_2013', '2012':'inflation_2012', '2011':'inflation_2011', '2010':'inflation_2010', '2009':'inflation_2009', '2008':'inflation_2008', '2007':'inflation_2007', '2006':'inflation_2006', '2005':'inflation_2005', '2004':'inflation_2004', '2003':'inflation_2003', '2002':'inflation_2002', '2001':'inflation_2001', '2000':'inflation_2000', '1999':'inflation_1999', '1998':'inflation_1998', '1997':'inflation_1997', '1996':'inflation_1996', '1995':'inflation_1995', '1994':'inflation_1994', '1993':'inflation_1993', '1992':'inflation_1992', '1991':'inflation_1991', '1990':'inflation_1990', '1989':'inflation_1989', '1988':'inflation_1988', '1987':'inflation_1987', '1986':'inflation_1986', '1985':'inflation_1985', '1984':'inflation_1984', '1983':'inflation_1983', '1982':'inflation_1982', '1981':'inflation_1981', '1980':'inflation_1980'}, inplace=True)

# Calculate COL values based on the formula
merged_df_8['COL_2021'] = merged_df_8['COL_2022'] / (1 + (merged_df_8['inflation_2022'] / 100))
merged_df_8['COL_2020'] = merged_df_8['COL_2021'] / (1 + (merged_df_8['inflation_2021'] / 100))
merged_df_8['COL_2019'] = merged_df_8['COL_2020'] / (1 + (merged_df_8['inflation_2020'] / 100))
merged_df_8['COL_2018'] = merged_df_8['COL_2019'] / (1 + (merged_df_8['inflation_2019'] / 100))
merged_df_8['COL_2017'] = merged_df_8['COL_2018'] / (1 + (merged_df_8['inflation_2018'] / 100))
merged_df_8['COL_2016'] = merged_df_8['COL_2017'] / (1 + (merged_df_8['inflation_2017'] / 100))
merged_df_8['COL_2015'] = merged_df_8['COL_2016'] / (1 + (merged_df_8['inflation_2016'] / 100))
merged_df_8['COL_2014'] = merged_df_8['COL_2015'] / (1 + (merged_df_8['inflation_2015'] / 100))
merged_df_8['COL_2013'] = merged_df_8['COL_2014'] / (1 + (merged_df_8['inflation_2014'] / 100))
merged_df_8['COL_2012'] = merged_df_8['COL_2013'] / (1 + (merged_df_8['inflation_2013'] / 100))
merged_df_8['COL_2011'] = merged_df_8['COL_2012'] / (1 + (merged_df_8['inflation_2012'] / 100))
merged_df_8['COL_2010'] = merged_df_8['COL_2011'] / (1 + (merged_df_8['inflation_2011'] / 100))
merged_df_8['COL_2009'] = merged_df_8['COL_2010'] / (1 + (merged_df_8['inflation_2010'] / 100))
merged_df_8['COL_2008'] = merged_df_8['COL_2009'] / (1 + (merged_df_8['inflation_2009'] / 100))
merged_df_8['COL_2007'] = merged_df_8['COL_2008'] / (1 + (merged_df_8['inflation_2008'] / 100))
merged_df_8['COL_2006'] = merged_df_8['COL_2007'] / (1 + (merged_df_8['inflation_2007'] / 100))
merged_df_8['COL_2005'] = merged_df_8['COL_2006'] / (1 + (merged_df_8['inflation_2006'] / 100))
merged_df_8['COL_2004'] = merged_df_8['COL_2005'] / (1 + (merged_df_8['inflation_2005'] / 100))
merged_df_8['COL_2003'] = merged_df_8['COL_2004'] / (1 + (merged_df_8['inflation_2004'] / 100))
merged_df_8['COL_2002'] = merged_df_8['COL_2003'] / (1 + (merged_df_8['inflation_2003'] / 100))
merged_df_8['COL_2001'] = merged_df_8['COL_2002'] / (1 + (merged_df_8['inflation_2002'] / 100))
merged_df_8['COL_2000'] = merged_df_8['COL_2001'] / (1 + (merged_df_8['inflation_2001'] / 100))
merged_df_8['COL_1999'] = merged_df_8['COL_2000'] / (1 + (merged_df_8['inflation_2000'] / 100))
merged_df_8['COL_1998'] = merged_df_8['COL_1999'] / (1 + (merged_df_8['inflation_1999'] / 100))
merged_df_8['COL_1997'] = merged_df_8['COL_1998'] / (1 + (merged_df_8['inflation_1998'] / 100))
merged_df_8['COL_1996'] = merged_df_8['COL_1997'] / (1 + (merged_df_8['inflation_1997'] / 100))
merged_df_8['COL_1995'] = merged_df_8['COL_1996'] / (1 + (merged_df_8['inflation_1996'] / 100))
merged_df_8['COL_1994'] = merged_df_8['COL_1995'] / (1 + (merged_df_8['inflation_1995'] / 100))
merged_df_8['COL_1993'] = merged_df_8['COL_1994'] / (1 + (merged_df_8['inflation_1994'] / 100))
merged_df_8['COL_1992'] = merged_df_8['COL_1993'] / (1 + (merged_df_8['inflation_1993'] / 100))
merged_df_8['COL_1991'] = merged_df_8['COL_1992'] / (1 + (merged_df_8['inflation_1992'] / 100))
merged_df_8['COL_1990'] = merged_df_8['COL_1991'] / (1 + (merged_df_8['inflation_1991'] / 100))
merged_df_8['COL_1989'] = merged_df_8['COL_1990'] / (1 + (merged_df_8['inflation_1990'] / 100))
merged_df_8['COL_1988'] = merged_df_8['COL_1989'] / (1 + (merged_df_8['inflation_1989'] / 100))
merged_df_8['COL_1987'] = merged_df_8['COL_1988'] / (1 + (merged_df_8['inflation_1988'] / 100))
merged_df_8['COL_1986'] = merged_df_8['COL_1987'] / (1 + (merged_df_8['inflation_1987'] / 100))
merged_df_8['COL_1985'] = merged_df_8['COL_1986'] / (1 + (merged_df_8['inflation_1986'] / 100))
merged_df_8['COL_1984'] = merged_df_8['COL_1985'] / (1 + (merged_df_8['inflation_1985'] / 100))
merged_df_8['COL_1983'] = merged_df_8['COL_1984'] / (1 + (merged_df_8['inflation_1984'] / 100))
merged_df_8['COL_1982'] = merged_df_8['COL_1983'] / (1 + (merged_df_8['inflation_1983'] / 100))
merged_df_8['COL_1981'] = merged_df_8['COL_1982'] / (1 + (merged_df_8['inflation_1982'] / 100))
merged_df_8['COL_1980'] = merged_df_8['COL_1981'] / (1 + (merged_df_8['inflation_1981'] / 100))

# Display or use the updated dataframe with 'COL_2021'
merged_df_8
# Out:
#           city country    tier  COL_2022  inflation_2022  inflation_2021  \
# 0       Mumbai   India  Tier 1   613.890            6.69            4.89
# 1        Delhi   India  Tier 1   333.990            6.69            4.89
# 2      Kolkata   India  Tier 2   224.335            6.69            4.89
# 3    Bangalore   India  Tier 1   310.190            6.69            4.89
# 4      Chennai   India  Tier 1   260.190            6.69            4.89
# ..         ...     ...     ...       ...             ...             ...
# 108   Udhampur   India  Tier 2   159.440            6.69            4.89
# 109  Dharmsala   India  Tier 2   209.750            6.69            4.89
# 110  Udayagiri   India  Tier 3   136.850            6.69            4.89
# 111  Cherukuru   India  Tier 3   116.230            6.69            4.89
# 112   Tirupati   India  Tier 2   148.820            6.69            4.89
#
#      inflation_2020  inflation_2019  inflation_2018  inflation_2017  \
# ...

# %%
# Drop the specified columns including inflation_2000 to inflation_1980
columns_to_drop = ['inflation_2022', 'inflation_2021', 'inflation_2020', 'inflation_2019', 'inflation_2018', 'inflation_2017', 'inflation_2016', 'inflation_2015', 'inflation_2014', 'inflation_2013', 'inflation_2012', 'inflation_2011', 'inflation_2010', 'inflation_2009', 'inflation_2008', 'inflation_2007', 'inflation_2006', 'inflation_2005', 'inflation_2004', 'inflation_2003', 'inflation_2002', 'inflation_2001']

# Add inflation_2000 to inflation_1980 to the list
columns_to_drop.extend([f'inflation_{year}' for year in range(2000, 1979, -1)])

# Drop the specified columns
merged_df_8.drop(columns=columns_to_drop, axis=1, inplace=True)

# Display or use the updated dataframe with 'COL_2021'
merged_df_8
# Out:
#           city country    tier  COL_2022    COL_2021    COL_2020    COL_2019  \
# 0       Mumbai   India  Tier 1   613.890  575.396007  548.570891  514.510308
# 1        Delhi   India  Tier 1   333.990  313.047146  298.452804  279.921969
# 2      Kolkata   India  Tier 2   224.335  210.268066  200.465313  188.018489
# 3    Bangalore   India  Tier 1   310.190  290.739526  277.185171  259.974837
# 4      Chennai   India  Tier 1   260.190  243.874777  232.505270  218.069096
# ..         ...     ...     ...       ...         ...         ...         ...
# 108   Udhampur   India  Tier 2   159.440  149.442309  142.475269  133.629027
# 109  Dharmsala   India  Tier 2   209.750  196.597619  187.432185  175.794584
# 110  Udayagiri   India  Tier 3   136.850  128.268816  122.288889  114.696013
# 111  Cherukuru   India  Tier 3   116.230  108.941794  103.862898   97.414086
# 112   Tirupati   India  Tier 2   148.820  139.488237  132.985258  124.728248
#
# ...

# %%
# Get the current column names
current_columns = merged_df_8.columns

# Extracting the year part and converting it into integers for relevant columns
new_columns = [col.split('_')[1] if col.startswith('COL_') else col for col in current_columns]

# Creating a dictionary to map current columns to new columns (with adjusted year names)
columns_mapping = dict(zip(current_columns, new_columns))

# Rename columns using the created mapping
merged_df_8 = merged_df_8.rename(columns=columns_mapping)

# %%
merged_df_8[merged_df_8['city']=='Vadodara']
# Out:
#         city country    tier     2022        2021        2020        2019  \
# 14  Vadodara   India  Tier 2  173.625  162.737839  155.150957  145.517686
#
#           2018        2017        2016        2015        2014        2013  \
# 14  138.905771  132.467835  127.864705  121.845536  115.089766  108.217928
#
#          2012       2011       2010       2009       2008       2007  \
# 14  97.572742  89.262411  81.997438  73.218536  66.034033  60.945116
#
#          2006       2005       2004       2003       2002       2001  \
# 14  57.295399  54.154441  51.946706  50.059465  48.222199  46.234131
#
#          2000       1999       1998       1997      1996      1995       1994  \
# 14  44.550136  42.832551  40.921516  36.140171  33.72543  30.94644  28.076973
#
#          1993       1992      1991       1990       1989       1988  \
# 14  25.466643  23.950571  21.42461  18.814973  17.266195  16.126081
#
# ...

# %% [markdown]
# #### Using the polynomial regression along with extrapolation approach to predict

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to predict cost for a given city and year
def predict_cost_of_living(years, city_data, city_name, prediction_year):
    coefficients = np.polyfit(years, city_data, 2)
    poly_function = np.poly1d(coefficients)

    # Plotting the polynomial curve
    plt.figure(figsize=(10, 6))
    plt.scatter(years, city_data, label='Cost of Living (Existing Data)', color='blue')
    plt.plot(years, poly_function(years), color='red', label='Polynomial Regression (Degree 2)')

    # Extending the curve to predict values for future years
    future_years = np.arange(2000, 2045)
    predicted_values = poly_function(future_years)
    plt.plot(future_years, predicted_values, color='green', linestyle='--', label=f'Extrapolation ({max(years) + 1} - {prediction_year})')

    plt.title(f'Cost of Living Trend in {city_name} (2012 - {prediction_year + 10})')
    plt.xlabel('Year')
    plt.ylabel('Cost of Living')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    # Annotation for a specific year
    x_annotation = prediction_year
    y_annotation = poly_function(x_annotation)
    plt.annotate(f'({x_annotation}, {y_annotation:.2f})', (x_annotation, y_annotation),
                 xytext=(-20, 20), textcoords='offset points',
                 arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5'))

    plt.show()

    # Calculate the derivative of the polynomial function
    derivative_function = np.polyder(poly_function)

    # Calculate the slope (derivative) at the given prediction year
    slope_at_prediction_year = derivative_function(prediction_year)
    print(f"The slope at {prediction_year} for {city_name} is: {slope_at_prediction_year:.2f}")

    # Return the predicted cost for the specified year
    return poly_function(prediction_year)

# # Sample data (Replace with actual data)
# years = list(range(2010, 2000, -1)) # Replace with actual years data
# city_data = merged_df_7.loc[merged_df_7['city'] == city_name, '2010':'2000'].values.flatten() # Replace with actual cost data
# #city_name = 'Mumbai'

# # Example usage
# #prediction_year = 2034  # Replace with the year you want to predict
# predicted_cost = predict_cost_of_living(years, city_data, city_name, prediction_year)
# print(f"The predicted cost of living in {city_name} for the year {prediction_year} is: {predicted_cost:.2f}")

city_name = 'Mumbai'
#years = np.array([2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000])  # Ensure this array has the correct length
years = list(range(2022, 1999, -1))
city_data = merged_df_8.loc[merged_df_8['city'] == city_name, '2022':'2000'].values.flatten()
prediction_year = 2024 # Replace with the year you want to predict
predicted_cost = predict_cost_of_living(years, city_data, city_name, prediction_year)
print(f"The predicted cost of living in {city_name} for the year {prediction_year} is: {predicted_cost:.2f}")
# Out:
# The slope at 2024 for Mumbai is: 36.05
# The predicted cost of living in Mumbai for the year 2024 is: 689.94

# %% [markdown]
# ## Conclusions

# %% [markdown]
# ### After doing extensive predictions with various data(various years to be the final years to be trained upto, various year duration and on two different cities, and also evaluating) we come with this

# %% [markdown]
# ### In this we used Mumbai and Vadodara to evaluate our model, we chose three years (2022, 2018, 2015) as our target years and trained the model with different data(various year timelines) to predict, then compared with already existing values and calculated accuracy in % for each observation

# %% [markdown]
# MUMBAI:
#
# PREDICTION OF COL OF 2022:
# ACTUAL VALUE = 613.89
#
# PREDICTED VALUES:
# - USING DATA UPTO 2021
# TRAIN FROM
#     * 2015-2021 = 610.23 // 99.41%
#     * 2012-2021 = 595.19 // 96.95%
#     * 2005-2021 = 601.07 // 97.91%
#     * 2000-2021 = 623.09 // 98.50%
# - USING DATA UPTO 2017
# TRAIN FROM
#     * 2011-2017 = 500.30 // 81.52%
#     * 2008-2017 = 564.97 // 92.04%
#     * 2001-2017 = 690.04 // 87.61%
#     * 1996-2017 = 674.81 // 90.08%
# - USING DATA UPTO 2011
# TRAIN FROM
#     * 2005-2011 = 946.93 // 45.79
#     * 2002-2011 = 874.12 // 57.67%
#     * 1995-2011 = 592.24 // 96.4%
#     * 1990-2011 = 501.72 // 81.73%
#
#
# PREDICTION OF COL OF 2018:
# ACTUAL VALUE = 491.13
#
# PREDICTED VALUES:
# - USING DATA UPTO 2017
# TRAIN FROM
#     * 2011-2017 = 482.00 // 98.14%
#     * 2008-2017 = 493.98 // 99.42%
#     * 2001-2017 = 526.77 // 92.73
#     * 1996-2017 = 520.93 // 93.93%
# - USING DATA UPTO 2013
# TRAIN FROM
#     * 2007-2013 = 591.50 // 79.53%
#     * 2004-2013 = 618.71 // 74.01%
#     * 1997-2013 = 550.23 // 87.98%
#     * 1992-2013 = 488.70 // 99.51%
# - USING DATA UPTO 2007
# TRAIN FROM
#     * 2001-2007 = 428.66 // 87.28%
#     * 1998-2007 = 369.45 // 75.23%
#     * 1991-2007 = 282.94 // 57.605
#     * 1986-2007 = 317.94 // 64.74%
#
#
# PREDICTION OF COL OF 2015:
# ACTUAL VALUE = 430.81
#
# PREDICTED VALUES:
# - USING DATA UPTO 2014
# TRAIN FROM
#     * 2008-2014 = 441.46 // 97.53%
#     * 2005-2014 = 451.50 // 95.20%
#     * 1998-2014 = 444.17 // 96.90%
#     * 1993-2014 = 420.26 //  97.55%
# - USING DATA UPTO 2010
# TRAIN FROM
#     * 2005-2010 = 520.03 // 79.32%
#     * 2001-2010 = 454.86 // 94.42%
#     * 1994-2010 = 357.45 // 83.01%
#     * 1989-2010 = 335.75 // 77.94%
# - USING DATA UPTO 2004
# TRAIN FROM
#     * 1998-2004 = 263.35 // 61.13%
#     * 1995-2004 = 182.60 // 42.46%
#     * 1988-2004 = 277.53 // 64.455
#     * 1983-2004 = 324.14 // 75.26%
#
#
#
#
#
#
#
#
# VADODARA:
#
# PREDICTION OF COL OF 2022:
# ACTUAL VALUE = 173.625
#
# PREDICTED VALUES:
# - USING DATA UPTO 2021
# TRAIN FROM
#     * 2015-2021 = 172.59 // 99.39%
#     * 2012-2021 = 168.34 // 96.95%
#     * 2005-2021 = 170.00 // 98.12%
#     * 2000-2021 = 176.23 // 98.48%
# - USING DATA UPTO 2017
# TRAIN FROM
#     * 2011-2017 = 141.50 // 81.70%
#     * 2008-2017 = 159.79 // 92.05%
#     * 2001-2017 = 195.16 // 86.77%
#     * 1996-2017 =  190.86 // 90.06%
# - USING DATA UPTO 2011
# TRAIN FROM
#     * 2005-2011 = 267.82 // 45.49%
#     * 2002-2011 = 247.23 // 57.68%
#     * 1995-2011 = 167.50 // 96.44%
#     * 1990-2011 = 141.90 // 81.91%
#
#
# PREDICTION OF COL OF 2018:
# ACTUAL VALUE = 138.90
#
# PREDICTED VALUES:
# - USING DATA UPTO 2017
# TRAIN FROM
#     * 2011-2017 = 136.32 // 98.06%
#     * 2008-2017 = 139.71 // 99.42%
#     * 2001-2017 = 148.98 // 92.88%
#     * 1996-2017 = 147.33 // 93.94%
# - USING DATA UPTO 2013
# TRAIN FROM
#     * 2007-2013 = 167.29 // 79.55%
#     * 2004-2013 = 174.99 // 74.12%
#     * 1997-2013 = 155.62 // 88.86%
#     * 1992-2013 = 138.22 // 99.50%
# - USING DATA UPTO 2007
# TRAIN FROM
#     * 2001-2007 =121.24 // 87.29%
#     * 1998-2007 = 104.49 // 75.29%
#     * 1991-2007 = 80.02 // 57.64%
#     * 1986-2007 = 89.92 // 64.65%
#
#
# PREDICTION OF COL OF 2015:
# ACTUAL VALUE = 121.84
#
# PREDICTED VALUES:
# - USING DATA UPTO 2014
# TRAIN FROM
#     * 2008-2014 = 124.86 // 97.53%
#     * 2005-2014 = 127.70 // 95.26%
#     * 1998-2014 = 125.62 // 96.98%
#     * 1993-2014 = 118.86 // 97.57%
# - USING DATA UPTO 2010
# TRAIN FROM
#     * 2005-2010 = 147.08 // 79.39%
#     * 2001-2010 = 128.65 // 94.39%
#     * 1994-2010 = 101.10// 82.99%
#     * 1989-2010 = 94.96 // 77.98%
# - USING DATA UPTO 2004
# TRAIN FROM
#     * 1998-2004 = 74.48 // 61.20%
#     * 1995-2004 = 51.64 // 42.34%
#     * 1988-2004 = 78.49 // 64.34%
#     * 1983-2004 = 91.68 // 75.325

# %% [markdown]
# ### What we can conclude from this is that:
# ### Keeping in mind that 2022 is the year upto which we have data and will train our model with,
# ### If we are predicting near future years (2023-2028), the accuracy remains pretty high, almost above 85%, and it decreases as we move farther away from 2022, so as we predict for years beyond 2030, for years 2035-2040 or beyond, the accuracy keeps decreasing and can go down to 60%
# ### But to counter this, what we have realized is that, if we want to predict the COL of years far beyond current year, we need to provide historical data of more years
# ### For example, it is seen that if we are predicting COL values beyond 10 years, then if we provide the model for the data of past 20 years, the accuracy increases

# %% [markdown]
# ### Also, 20 years historical data is useful for near future prediction as well, because in near future prediction, the accuracy goes up by 5-10% when we increase the number of years of data used to train
# ### So to not make it very complex, keep it simple and maximize the accuracy, we will be using data from 2000-2022 as of now to predict future values
